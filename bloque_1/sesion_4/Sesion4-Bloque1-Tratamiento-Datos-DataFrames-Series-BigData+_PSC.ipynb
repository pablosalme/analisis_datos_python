# %% [markdown]
# # Módulo 1: Análisis de datos en el ecosistema Python

# %% [markdown]
# ### Sesión (4)

# %% [markdown]
# **25/09/2023**

# %% [markdown]
# # Exploración y tratamiento de datos

# %% [markdown]
# Breve resumen de herramientas principales de tratamiento de datos en Python:
#
# #### **Numpy:**
# * Paquete específico muy útil para trabajar con **arrays y matrices**.
# * Podemos crear arrays desde cero (útil cuando queremos arrays **multidimensionales**).
#
#
# #### **Matplotlib:**
# * Paquete para pintar **gráficos** a partir de datos contenidos en listas o arrays.
# * Utiliza la extensión matemática de *numpy*.
#
# #### **Pandas:**
# * Paquete que sirve para trabajar con datos (vectores, series y tablas).
# * La librería Pandas dispone de tres estructuras principales:
#     * __DataFrames__
#     * __Series__
#     * __Index__

# %% [markdown]
# ## Gráficos
# Existen varias librerías y paquetes para pintar gráficos en python. Uno de los más populares es el **[matplotlip](https://matplotlib.org/stable/)**, que tiene una sintaxis que proviene de **Matlab**.
#
# Para usarlo en Jupyter vamos a utilizar un [comando "mágico"](http://ipython.readthedocs.io/en/stable/interactive/magics.html). Jupyter permite hacer cosas que no son código Python, el que vamos a usar aquí configura a Jupyter de tal manera que la salida de los gráficos de matplotlib se muestre en el propio cuaderno (en vez de guardarse en un archivo separado).

# %%
# Esta celda suele estar en todos los notebooks que hagan análisis o tratamientos de datos
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Pintamos un gráfico sencillo a partir de un conjunto de puntos:

# %%
# Por defecto se pinta un "line plot"
plt.plot([10,20,30,40], [200,300,400,100])
plt.xlabel('Tiempo [min]')
plt.ylabel('Potencia [kW]')
plt.title('Motor 1')
plt.show()

# %%
# Podemos personalizar el gráfico indicando muchas opciones
plt.plot([10,20,30,40], [200,300,400,100], color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=12)
plt.xlabel('Tiempo [min]')
plt.ylabel('Potencia [kW]')
plt.title('Motor 1')
plt.show()

# %% [markdown]
# Se pueden modificar los parámetros de estilado por defecto de **matplotlib** mediante [rcParams (runtime configuration Parameters)](https://matplotlib.org/3.5.0/api/matplotlib_configuration_api.html#matplotlib.rcParams)

# %%
# Modificar los parámetros del gráfico para toda la sesión
plt.rcParams['figure.figsize'] = 12, 6 # el primer dígito es el ancho y el segundo el alto
plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 10
plt.rcParams["axes.labelweight"] = "bold"

# %%
plt.plot([10,20,30,40], [200,300,400,100], color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=12)

plt.xlabel('Tiempo [min]', fontsize='large', fontweight='bold')
plt.ylabel('Potencia [kW]', fontsize='large', fontweight='bold')
plt.title('Motor 1', fontsize=20, fontweight='bold')

plt.show()

# %%
# Para volver a los valores y los ajustes por defecto
plt.rcdefaults()

# %%
# El mismo gráfico ésta vez con parámetros y ajustes por defecto!!
plt.plot([10,20,30,40], [200,300,400,100], color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=12)

plt.xlabel('Tiempo [min]', fontsize='large', fontweight='bold')
plt.ylabel('Potencia [kW]', fontsize='large', fontweight='bold')
plt.title('Motor 1', fontsize=20, fontweight='bold')

plt.show()

# %%
## Un ejemplo más avanzado
# En numpy sabemos que la función np.linspace() nos permite crear un array con valores equidistantes
X = np.linspace(-np.pi, np.pi, 180)
Coseno = np.cos(X)
Seno = np.sin(X)

# Usamos la opción scatterplot que pinta solamente los puntos en vez de dibujar lineas
plt.scatter(X, Coseno, s=10)
plt.scatter(X, Seno, s=10)

plt.show()

# %% [markdown]
# ### **`Ejercicio 4.1`**
#
# **`4.1.1`** Crea un gráfico con puntos rojos que visualice el valor de cada número **elevado al cubo** (elevar cada número a la tercera potencia) para `101` números repartidos de forma equidistantes entre `0` y `10` (_inclusive_).

# %%
## Solución
# Ejercicio 4.1.1
x = np.linspace(0,10,101)
cubo = x**3
plt.scatter(x, cubo, s=10, color = "red")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Pandas

# %% [markdown]
# * **Pandas** es un paquete basado en **numpy** y otros que sirve para trabajar con datos.
#
# * Pandas incorpora muchas cosas que facilitan el análisis de datos:
#     * Arrays etiquetados (**labeled arrays**).
#     * Introducir datos heterogéneos en una tabla (similar a los **DataFrames** de *R*).
#     * Los valores perdidos (**missing values**) se manejan mejor.
#     * **Funciones** útiles estadísticas, para pintar gráficos, calcular nuevas variables, etc.
#     * Diversos **tipos** de datos (**Categorical** para variables categóricas, **Datetime** para fechas).
#
# * Para poder empezar a usar a *pandas* necesitamos tener instalado el *numpy*, después podemos importar *pandas* mediante el comando `import` que por convenio suele importarse bajo el acrónimo de `pd`
#
# * La librería Pandas dispone de tres estructuras principales:
#     * **Series**
#     * **DataFrames**
#     * **Index**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas Series
#
# * Un pandas series se trata de **un array unidimensional indexado** o mejor dicho **etiquetado**.
#
# * Este tipo de datos pueden ser creados a partir de un array unidimensional o a partir de una lista.

# %%
# Nos creamos un objeto tipo serie
data = pd.Series([10, 20, 15, 10, 17], index = ['a', 'b', 'c', 'd','e'])

# Mostramos el resultado
print(data)
type(data)
# Out:
# a    10
# b    20
# c    15
# d    10
# e    17
# dtype: int64
# pandas.core.series.Series

# %% [markdown]
# Una serie dispone tanto de una **secuencia de valores** (los datos de nuestra _lista_/_array_), además de una **secuencia de índices**.
#
# * Podemos acceder tanto a los valores como a los índices mediante los atributos: `.values` e `.index` respectivamente.
# * Podemos consultar otras características de una serie mediante `.size ` (devuelve el número de elementos de la serie) y `.dtype` (devuelve el tipo de datos de los elementos de la serie).

# %%
# Accedemos a los valores de nuestra serie
print(data.values)

# Vemos su tipo 
print(type(data.values))

# Accedemos a los índices
print(data.index) 

# Consultamos el tipo de datos para los índices
print(type(data.index)) 

# Consultamos el número de elementos de la serie
print(data.size) 

# Consultamos el tipo de datos de los elementos de la serie
print(data.dtype)
# Out:
# [10 20 15 10 17]
# <class 'numpy.ndarray'>
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# 5
# int64

# %% [markdown]
# ### Funciones (métodos) para  Series

# %% [markdown]
# Algunos **métodos para Series**:
# * **`.value_counts()`:** Devuelve un objeto que contiene **en orden de frecuencia**, los **distintos valores existentes** en la serie junto con el **número de apariciones** de cada uno.
# * **`.unique()`:** Devuelve un array con los **valores únicos** de la serie.
# * **`.sort_values()`:** Devuelve la serie con **valores ordenados**. Por defecto en orden **ascendiente**.

# %%
data
# Out:
# a    10
# b    20
# c    15
# d    10
# e    17
# dtype: int64

# %%
data.value_counts()
# Out:
# 10    2
# 20    1
# 15    1
# 17    1
# dtype: int64

# %%
data.value_counts().index
# Out:
# Int64Index([10, 20, 15, 17], dtype='int64')

# %%
data.unique()
# Out:
# array([10, 20, 15, 17])

# %%
data.sort_values()
# Out:
# a    10
# d    10
# c    15
# e    17
# b    20
# dtype: int64

# %% [markdown]
# Podemos acceder a los datos concretos a través de sus índices, de igual forma que hacíamos en un numpy arrays, haciendo uso de los **corchetes**.

# %%
print("La serie =")
print(data)

# Accedemos al primer valor de nuestra serie (como si fuera un array)
print("\n Primer elemento =", data[0])
# Out:
# La serie =
# a    10
# b    20
# c    15
# d    10
# e    17
# dtype: int64
#
#  Primer elemento = 10

# %%
# Accedemos al segundo y al tercer elemento de nuestra serie
data[1:3]
# Out:
# b    20
# c    15
# dtype: int64

# %%
# Accedemos al elemento con índice "b"  de nuestra serie
data['b']
# Out:
# 20

# %%
# Accedemos a los elementos con índice "a","b","c" de nuestra serie (aquí sí que se incluye el índice final)
data['a':'c']
# Out:
# a    10
# b    20
# c    15
# dtype: int64

# %% [markdown]
# Al igual que otros objetos mutables que hemos visto anteriormente, las series en pandas también se pueden modificar cuando se referencian por el indexado.

# %%
# Modificamos el primer elemento referenciando su posición
data[0] = 88
data
# Out:
# a    88
# b    20
# c    15
# d    10
# e    17
# dtype: int64

# %%
# Modificamos el último elemento referenciando su índice
data['e'] = 99
data
# Out:
# a    88
# b    20
# c    15
# d    10
# e    99
# dtype: int64

# %% [markdown]
# * Podríamos pensar que un objeto _pandas series_ se trata de una **especialización de un diccionario**.
# * Un diccionario se trata de una estructura que asigna un conjunto de claves arbitrarias a un conjunto de valores arbitrarios, mientras que una **Serie** asigna un conjunto de **claves tipadas** (lo que significa que deben ser del mismo tipo) a un conjunto de **valores tipados**.
# * Esta tipificación es importante, porque de igual forma que el código compilado que corre detrás de un _numpy array_ la hace más eficiente que una lista _Python_ para ciertas operaciones, el tipado de los datos de una _Serie_ hace que esta sea mucho más eficiente que un diccionario para ciertas operaciones.

# %% [markdown]
# Podemos crear series a partir de diccionarios y diccionarios a partir de series.
# Por defecto las series son ordenadas por clave en sentido ascendente.
# Veamos el ejemplo de los ganadores de [Champions League:](https://es.uefa.com/uefachampionsleague/history/rankings/)

# %%
# Nos creamos una serie a partir de un diccionario
champions_dict = {'Real_Madrid': 14, 'Milan': 7, 'Liverpool': 6, 'Bayern_Munich': 6, 'Barcelona': 5}

# Mostramos el diccionario
print(champions_dict)
type(champions_dict)
# Out:
# {'Real_Madrid': 14, 'Milan': 7, 'Liverpool': 6, 'Bayern_Munich': 6, 'Barcelona': 5}
# dict

# %%
# Nos creamos nuestro pandas series a partir del diccionario
champions_series = pd.Series(champions_dict)

#Mostramos el resultado
print(champions_series)
type(champions_series)
# Out:
# Real_Madrid      14
# Milan             7
# Liverpool         6
# Bayern_Munich     6
# Barcelona         5
# dtype: int64
# pandas.core.series.Series

# %%
# Las claves del diccionario original son los índices o las etiquetas de la serie
champions_series.index
# Out:
# Index(['Real_Madrid', 'Milan', 'Liverpool', 'Bayern_Munich', 'Barcelona'], dtype='object')

# %%
# Consultamos la estadística de los dos primeros equipos
champions_series[0:2]
# Out:
# Real_Madrid    14
# Milan           7
# dtype: int64

# %%
# Consultamos por el índice/clave asociada
champions_series['Barcelona']
# Out:
# 5

# %% [markdown]
# ## Dataframe
#
# * Si una serie es una analogía de un array unidimensional con índices etiquetados, un **DataFrame** es análogo a **un array bidimensional con flexibilidad de indexación** tanto para las <ins>filas</ins> como para las <ins>columnas</ins>.
# * Podemos pensar en un **DataFrame** como objetos de tipo serie alineados. Aquí la palabra alineado quiere decir que estos objetos tipo serie (columnas) comparten el mismo índice.

# %% [markdown]
# Los objetos _Pandas DataFrame_ se pueden construir de diferentes formas, a continuación veremos algunas de estas.
# * **A partir de una Serie:** Como ya hemos indicado un DataFrame es una colección de objetos tipo serie (_pandas Series_), por lo que a partir de una sola _Serie_ podemos crear un objeto de tipo _DataFrame_.
#
# * **A partir de datos guardados en formato tabular:** Se pueden crear _DataFrames_ por ejemplo a partir de un archivo *csv* o *Excel*.
#
# * **A partir de un diccionario:** Cualquier diccionario o lista de diccionarios puede ser transformada a un objeto de tipo _DataFrame_.

# %%
# Crear un DataFrame directamente con la serie de champions
df_champions = pd.DataFrame(champions_series)
print(type(df_champions))
df_champions
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                 0
# Real_Madrid    14
# Milan           7
# Liverpool       6
# Bayern_Munich   6
# Barcelona       5

# %%
# Crear un conjunto de pandas series con índices iguales
serie_temp = pd.Series({'a': 150, 'b': 100, 'c': 110})
serie_func = pd.Series({'a': True, 'b': False, 'c': False})
serie_pot = pd.Series({'a': 160, 'b': 180, 'c': 240})

# Crear un diccionario etiquetando cada serie
dicc_series = {'Temperatura': serie_temp,
                'Funcionalidad': serie_func,
                'Potencia': serie_pot}

# Crear un DataFrame con el conjunto de las series etiquetadas
df_1 = pd.DataFrame(dicc_series)
print(type(df_1))
df_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# b          100          False       180
# c          110          False       240

# %%
# Creamos un DataFrame a partir de un diccionario que directamente contiene los valores de tres variables.
# El "index" define la secuencia de las variables e indica que todas tienen los mismos índices (si no lo ponemos se crea uno por defecto con números).

dicc = {'Temperatura': [150, 100, 110, 95, 85],
        'Funcionalidad': [True, False, False, True, False],
        'Potencia': [160, 180, 240, 160, 185]}

df = pd.DataFrame(dicc, index=['a', 'b', 'c', 'd', 'e'])
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# b          100          False       180
# c          110          False       240
# d           95           True       160
# e           85          False       185

# %%
# Mostramos los índices
print(df.index)

# Obtenemos y mostramos las etiquetas (los nombres de las columnas)
columns = df.columns
columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# Index(['Temperatura', 'Funcionalidad', 'Potencia'], dtype='object')

# %% [markdown]
# ## Pandas Index
# Ya hemos visto que los objetos tipo _Serie_ y tipo _DataFrame_ contienen **índices** que nos permiten referenciar y modificar sus datos. Este objeto de tipo **index** se trata de una estructura muy interesante que además de ayudarnos a seleccionar los datos, también sirven para hacer operaciones entre varios DataFrames.
#
# Aquí simplemente accedemos a estos datos de la siguiente forma y consultamos el tipo de dato que tienen asignado:

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
print(type(df.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %% [markdown]
# Este es un índice muy basico, pero los hay de más tipos como:
# - `MultiIndex` para índices multidimensionales (jerárquicos)
# - `DatetimeIndex` para usar fechas
# - `Float64Index` para floats
# - `CategoricalIndex` para categorías
# - `RangeIndex ` para rangos

# %% [markdown]
# Aunque los objetos de tipo `Index` se tratan de objetos **inmutables** y una vez creados no podemos modificar su contenido, podemos aplicarles la indexación estándar de Python y además disponen de muchos de los atributos de los arrays de numpy.

# %%
# Obtemos el primer valor de nuestro objeto index
ind = df.index
ind[0]
# Out:
# 'a'

# %%
# Eso sí, son inmodificables
ind[0] = 'aaa'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/pablo/BD/analisis_datos_python_Elias/sesion_4/Sesion4-Bloque1-Tratamiento-Datos-DataFrames-Series-BigData+_PSC.ipynb Celda 61 line 2
#       <a href='vscode-notebook-cell:/Users/pablo/BD/analisis_datos_python_Elias/sesion_4/Sesion4-Bloque1-Tratamiento-Datos-DataFrames-Series-BigData%2B_PSC.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> # Eso sí, son inmodificables
# ----> <a href='vscode-notebook-cell:/Users/pablo/BD/analisis_datos_python_Elias/sesion_4/Sesion4-Bloque1-Tratamiento-Datos-DataFrames-Series-BigData%2B_PSC.ipynb#Y114sZmlsZQ%3D%3D?line=1'>2</a> ind[0] = 'aaa'
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5302, in Index.__setitem__(self, key, value)
#    5300 @final
#    5301 def __setitem__(self, key, value):
# -> 5302     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# Obtenemos el número de elementos, tamaño, dimensión y el tipo de dato que contiene nuestro objeto de tipo index
print("Los índices = ",ind)
print("Número de elementos = ", ind.size)
print("Tamaño = ", ind.shape)
print("Dimensiones = ",ind.ndim)
print("Tipo = ", ind.dtype)
ind
# Out:
# Los índices =  Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# Número de elementos =  5
# Tamaño =  (5,)
# Dimensiones =  1
# Tipo =  object
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# ### **`Ejercicio 4.2`**
#
# **`4.2.1`** Define una función genérica usando el método `lambda` para convertir un array a una pandas series con valores enteros.
# **`4.2.2`** Aplica la función definida en el paso anterior sobre estos datos: `[10, True, 8.00, False, 8, 10]`
# **`4.2.3`** Consulta la siguiente información respecto a la serie creada en el paso anterior:
# - valores de la serie
# - índices de la serie
# - tipo de datos que contiene la serie
# - número de bits que ocupa en la memoria la serie
#
# **`4.2.4`** Genera un DataFrame con una columna que se llame `'ej_42'`a partir de la serie.

# %%
## Solución
# Ejercicio 4.2.1
convertir_array_series = lambda x: pd.Series(x, dtype='int')

# %%
## Solución
# Ejercicio 4.2.2
data = [10,True,8.00,False,8,10]
serie = convertir_array_series(data)
serie
# Out:
# 0    10
# 1     1
# 2     8
# 3     0
# 4     8
# 5    10
# dtype: int64

# %%
## Solución
# Ejercicio 4.2.3
"""- valores de la serie
- índices de la serie
- tipo de datos que contiene la serie
- número de bits que ocupa en la memoria la serie  """

print("Valores = ",serie.values)
print("Índices = ",serie.index)
print("Tipo de datos = ",serie.dtype)
print("Nº Bits = ",serie.nbytes)
# Out:
# Valores =  [10  1  8  0  8 10]
# Índices =  RangeIndex(start=0, stop=6, step=1)
# Tipo de datos =  int64
# Nº Bits =  48

# %%
## Solución
# Ejercicio 4.2.4
# Genera un DataFrame con una columna que se llame `'ej_42'`a partir de la serie.
df = pd.DataFrame(serie, columns=['ej_42'])
df
# Out:
#    ej_42
# 0     10
# 1      1
# 2      8
# 3      0
# 4      8
# 5     10

# %% [markdown]
# ---

# %% [markdown]
# ## DataFrame Slicing

# %% [markdown]
# Para los _DaraFrames_ existen diferentes maneras de seleccionar y filtrar los datos:
# 1. Filtrar usando `[]` para seleccionar **columnas** por sus nombres o **un rango de filas**.
# 2. Filtrar usando `.loc[etiquetas_filas, etiquetas_columna]` para seleccionar según las **etiquetas**.
# 3. Filtrar usando `.iloc[posiciones_filas, posiciones_columnas]` para seleccionar según las **posiciones**.
# 4. Filtrar por <ins>_indexado booleano_</ins> para seleccionar simplemente los datos que cumplan las **condiciones** declaradas.

# %%
# Consultamos de nuevo el contenido y el tipo de nuestro DataFrame
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# b          100          False       180
# c          110          False       240
# d           95           True       160
# e           85          False       185

# %% [markdown]
# #### 1. Ejemplos con **`[]`**

# %%
# Seleccionar una sola columna devuelve una Serie
print(df['Temperatura'])

type(df['Temperatura'])
# Out:
# a    150
# b    100
# c    110
# d     95
# e     85
# Name: Temperatura, dtype: int64
# pandas.core.series.Series

# %%
# Se puede seleccionar una lista de columnas (la primera y la última por ejemplo)
columnas = ['Temperatura', 'Potencia']

# En este caso el resultado es un DataFrame filtrado (por contener la unión de varias series)
print(type(df[columnas]))

df[columnas]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Temperatura  Potencia
# a          150       160
# b          100       180
# c          110       240
# d           95       160
# e           85       185

# %% [markdown]
# #### 2. Ejemplos con **`.loc[]`**

# %%
# Seleccionar una sola fila devuelve una Serie
print(type(df.loc['c']))

df.loc['c']
# Out:
# <class 'pandas.core.series.Series'>
# Temperatura        110
# Funcionalidad    False
# Potencia           240
# Name: c, dtype: object

# %%
# Se puede seleccionar una lista de filas (la primera y la penúltima por ejemplo)
filas = ['a', 'd']

# En este caso el resultado es un DataFrame filtrado (por contener un subconjunto de varias series)
print(type(df.loc[filas]))

df.loc[filas]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# d           95           True       160

# %%
# Se puede llegar a seleccionar un elemento concreto usando .loc[] indicando el nombre/etiqueta de la fila y la columna correspondiente
# Escogemos el último elemento de la tabla
df.loc['e', 'Potencia']
# Out:
# 185

# %%
df
# Out:
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# b          100          False       180
# c          110          False       240
# d           95           True       160
# e           85          False       185

# %%
# filas "c" y "d", columnas "Temperatura" y "Potencia"
df.loc[['c', 'd'], ['Temperatura', 'Potencia']]
# Out:
#    Temperatura  Potencia
# c          110       240
# d           95       160

# %% [markdown]
# #### 3. Ejemplos con **`.iloc[]`**

# %%
# Aplicando .iloc[] Podemos usar el indexado habitual de numpy como si nuestro DataFrame fuera un array bidimensional

# Seleccionamos el último elemento de la tabla
print(df.iloc[-1,-1])

# Seleccionamos el primer elemento de la tabla
print(df.iloc[0,0]) 

df
# Out:
# 185
# 150
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# b          100          False       180
# c          110          False       240
# d           95           True       160
# e           85          False       185

# %% [markdown]
# Seleccionar una sola columna o una sola fila devuelve una _Serie_

# %%
# Seleccionar la última columna 
print(type(df.iloc[:,-1]))
df.iloc[:,-1]
# Out:
# <class 'pandas.core.series.Series'>
# a    160
# b    180
# c    240
# d    160
# e    185
# Name: Potencia, dtype: int64

# %%
# Seleccionar la última fila 
print(type(df.iloc[-1,:]))
df.iloc[-1,:]
# Out:
# <class 'pandas.core.series.Series'>
# Temperatura         85
# Funcionalidad    False
# Potencia           185
# Name: e, dtype: object

# %%
# Al igual que el indexado de arrays bidimensionales en numpy, si indicamos solamente un índice se selecciona la fila entera
df.iloc[-1]
# Out:
# Temperatura         85
# Funcionalidad    False
# Potencia           185
# Name: e, dtype: object

# %%
# Podemos seleccionar un rango de filas (también funciona como vimos simplemente con los corchetes: df[0:3])
df.iloc[0:3]
# Out:
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# b          100          False       180
# c          110          False       240

# %%
# Seleccionar elementos de la segunda y la tercera fila y de la segunda y la tercera columna
df.iloc[1:3,1:]
# Out:
#    Funcionalidad  Potencia
# b          False       180
# c          False       240

# %% [markdown]
# #### 4. Ejemplos con máscaras (**indexado booleano**)

# %%
# Filtrando el dataframe y quedando solo con las filas con una temperatura mayor que 100
df[df["Temperatura"]>100]
# Out:
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# c          110          False       240

# %%
# Filtrando por temperatura mayor que 100 y quedando solamente con las dos últimas columnas
df.loc[df["Temperatura"]>100, ['Funcionalidad', 'Potencia']]
# Out:
#    Funcionalidad  Potencia
# a           True       160
# c          False       240

# %%
data
# Out:
# 0       10
# 1     True
# 2      8.0
# 3    False
# 4        8
# 5       10
# dtype: object

# %% [markdown]
# Además de filtrado, podemos crear y añadir nuevas filas y columnas a raíz de las filas y las columnas existentes

# %%
# Añadir una nueva fila con el índice 'f' que consiste en replicar los valores de la primera fila 'a'
df.loc['f'] = df.loc['a']
df
# Out:
#    Temperatura  Funcionalidad  Potencia
# a          150           True       160
# b          100          False       180
# c          110          False       240
# d           95           True       160
# e           85          False       185
# f          150           True       160

# %%
# Crear una nueva columna para indicar la potencia en MW 
df['Potencia_MW'] = df['Potencia']/1000
df
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a          150           True       160        0.160
# b          100          False       180        0.180
# c          110          False       240        0.240
# d           95           True       160        0.160
# e           85          False       185        0.185
# f          150           True       160        0.160

# %% [markdown]
# ### Métodos para los DataFrames
# * **`.head()`** muestra las primeras filas del _DataFrame_ (por defecto las 5 primeras) y es muy útil para cuando tenemos muchas filas.
# * **`.mean()`** muestra la media calculada para cada columna.
# * **`.describe()`** muestra un resumen de todas las columnas, con cálculos **estadísticos básicos** (solo lo hace para las columnas numéricas).

# %%
df.head()
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a          150           True       160        0.160
# b          100          False       180        0.180
# c          110          False       240        0.240
# d           95           True       160        0.160
# e           85          False       185        0.185

# %%
# Media de una columna
df['Potencia'].mean()
# Out:
# 180.83333333333334

# %%
# Media de todas las columnas (para la columna "Funcionalidad" convierte True a 1 y False a 0)
df.mean()
# Out:
# Temperatura      115.000000
# Funcionalidad      0.500000
# Potencia         180.833333
# Potencia_MW        0.180833
# dtype: float64

# %%
df.describe() # Sólo las columnas numéricas
# Out:
#        Temperatura    Potencia  Potencia_MW
# count     6.000000    6.000000     6.000000
# mean    115.000000  180.833333     0.180833
# std      28.284271   31.051033     0.031051
# min      85.000000  160.000000     0.160000
# 25%      96.250000  160.000000     0.160000
# 50%     105.000000  170.000000     0.170000
# 75%     140.000000  183.750000     0.183750
# max     150.000000  240.000000     0.240000

# %%
# Podemos hacer visiualizaciones rápidas (por debajo se usa matplotlib)
df.plot()
# Out:
# <Axes: >

# %%
# Podemos visualizar una variable (columna) concreta
df['Temperatura'].plot()
# Out:
# <Axes: >

# %%
# De la columna 'Potencia', podemos hacer un histograma
df['Potencia'].hist()
# Out:
# <Axes: >

# %%
df
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a          150           True       160        0.160
# b          100          False       180        0.180
# c          110          False       240        0.240
# d           95           True       160        0.160
# e           85          False       185        0.185
# f          150           True       160        0.160

# %%
# Para la columna 'Potencia' consultamos la frecuencia de los valores
df['Potencia'].value_counts()
# Out:
# 160    3
# 180    1
# 240    1
# 185    1
# Name: Potencia, dtype: int64

# %%
# Para la columna 'Potencia' consultamos los valores únicos
df['Potencia'].unique()
# Out:
# array([160, 180, 240, 185])

# %% [markdown]
# ### Tratando los valores perdidos
# _Pandas_ maneja los valores **None** y **NaN** indistintamente para indicar valores perdidos. Para facilitar el tratamiento de estos valores existen métodos que nos permiten detectar, imputar o eliminar estos valores perdidosn:
#
# * **`isnull()`** y **`isna()`:** generan una máscara booleana indicando los valores perdidos.
#
# * **`notnull()`** y **`notna()`:** opuestos a _isnull()_ y _isna()_, es decir, generan una máscara indicando los valores que no son perdidos.
#
# * **`dropna()`:** retorna una versión filtrada de los datos sin valores perdidos.
#
# * **`fillna()`:** retonar una versión de los datos con los valores perdidos imputados o rellenos.

# %%
# Modificamos algunos elementos para introducir valores perdidos (cambiando su valor a NaN)
df.loc['a', 'Potencia'] = df.loc['c', 'Potencia'] = np.nan
df.loc['b', 'Temperatura'] = df.loc['f', 'Temperatura'] = np.nan
df
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a        150.0           True       NaN        0.160
# b          NaN          False     180.0        0.180
# c        110.0          False       NaN        0.240
# d         95.0           True     160.0        0.160
# e         85.0          False     185.0        0.185
# f          NaN           True     160.0        0.160

# %%
df.isnull()
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a        False          False      True        False
# b         True          False     False        False
# c        False          False      True        False
# d        False          False     False        False
# e        False          False     False        False
# f         True          False     False        False

# %%
df.isna()
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a        False          False      True        False
# b         True          False     False        False
# c        False          False      True        False
# d        False          False     False        False
# e        False          False     False        False
# f         True          False     False        False

# %%
df.notnull()
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a         True           True     False         True
# b        False           True      True         True
# c         True           True     False         True
# d         True           True      True         True
# e         True           True      True         True
# f        False           True      True         True

# %%
# Por defecto se quitan aquellas filas que contengan algún valor nulo
df.dropna()
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# d         95.0           True     160.0        0.160
# e         85.0          False     185.0        0.185

# %%
# Se puede indicar en el argumento 'axis' que se eliminen las columnas con valores perdidos en vez de filas
df.dropna(axis='columns')
# Out:
#    Funcionalidad  Potencia_MW
# a           True        0.160
# b          False        0.180
# c          False        0.240
# d           True        0.160
# e          False        0.185
# f           True        0.160

# %%
# Rellenar los valores perdidos 
df.fillna(0)
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a        150.0           True       0.0        0.160
# b          0.0          False     180.0        0.180
# c        110.0          False       0.0        0.240
# d         95.0           True     160.0        0.160
# e         85.0          False     185.0        0.185
# f          0.0           True     160.0        0.160

# %% [markdown]
# ### Operando con valores perdidos

# %%
# Nos creamos un numpy array con uno de sus valores igual a NaN
valores = np.array([1, 2, 3, np.nan])
print(valores)
print(valores.dtype)
# Out:
# [ 1.  2.  3. nan]
# float64

# %%
# Realizamos unos calculos sobre el array (cualquier operación que contenga un valor NaN devolverá NaN)
print(valores.sum())
print(valores.min())
print(valores.max())
# Out:
# nan
# nan
# nan

# %% [markdown]
# Numpy dispone de operaciones especiales que ignoran estos valores perdidos: **`np.nansum()`** , **`np.nanmin()`** , **`np.nanmax()`**

# %%
#Hacemos uso de las funciones que ignoran los valores perdidos
print(np.nansum(valores))
print(np.nanmin(valores))
print(np.nanmax(valores))
# Out:
# 6.0
# 1.0
# 3.0

# %% [markdown]
# ### Funciones en DataFrames

# %% [markdown]
# Breve recordatorio sobre las **funciones _lambda_**:
# * A veces necesitamos tener funciones que son tan sencillas que no merece la pena ni siquiera que tengan nombre o estén declaradas.
# * Existe una sintaxis para hacer eso en Python en una sola línea.
# * Se utiliza la palabra clave _lambda_ seguida de las variables, dos puntos y la expresión: `lamda variables: expresión`

# %% [markdown]
# El método **`apply()`:**  Este método nos permite aplicar una función arbitraria a cada uno de los grupos. La función debería tomar un DataFrame y devolver un objeto tipo Pandas (DataFrame o Series).

# %%
df
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a        150.0           True       NaN        0.160
# b          NaN          False     180.0        0.180
# c        110.0          False       NaN        0.240
# d         95.0           True     160.0        0.160
# e         85.0          False     185.0        0.185
# f          NaN           True     160.0        0.160

# %%
# Devuelve una serie con la suma de todos los elementos (axis=0 para las columnas)
df.apply(np.sum, axis=0)
# Out:
# Temperatura      440.000
# Funcionalidad      3.000
# Potencia         685.000
# Potencia_MW        1.085
# dtype: float64

# %%
# axis=1 para las filas
df.apply(np.sum, axis=1)
# Out:
# a    151.160
# b    180.180
# c    110.240
# d    256.160
# e    270.185
# f    161.160
# dtype: float64

# %%
# ejemplo de apply usando la función lambda, sumo 1 a todos los datos del DataFrame 
df.apply(lambda x: x + 1)
# Out:
#    Temperatura  Funcionalidad  Potencia  Potencia_MW
# a        151.0              2       NaN        1.160
# b          NaN              1     181.0        1.180
# c        111.0              1       NaN        1.240
# d         96.0              2     161.0        1.160
# e         86.0              1     186.0        1.185
# f          NaN              2     161.0        1.160

# %% [markdown]
# ### **`Ejercicio 4.3`**
#
# Cargamos el Dataset de [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) que contiene datos del consumo de combustible de diversos modelos de coches.
#
# **`4.3.1`** ¿Qué coche pesa más de 5000 kg?
# **`4.3.2`** ¿Cuál es el número de cilindros más frecuente en los coches que son del año 76?
# **`4.3.3`** Compara el consumo medio de los coches fabricados en el año 70 con el consumo de los fabricados en el año 79 y calcula la diferencia.
# **`4.3.4`** Identifica las variables que contienen valores nulos (missing values) en caso de que haya alguna.
# **`4.3.5`** Crea un _DataFrame_ con los modelos con 6 o más cilindros, que pesen más de 4000 kg y consumen menos o igual que 10 galón por milla, filtrando el dataset original.

# %%
# Descargar los datos desde la página de UCI

path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, delim_whitespace=True, header=None,
            names = ['mpg', 'cilindros', 'desplazamiento','potencia',
            'peso', 'aceleración', 'año', 'origen', 'nombre'],
            na_values='?')

# El DataFrame que se carga
mpg_data
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleración  año  \
# 0    18.0          8           307.0     130.0  3504.0         12.0   70
# 1    15.0          8           350.0     165.0  3693.0         11.5   70
# 2    18.0          8           318.0     150.0  3436.0         11.0   70
# 3    16.0          8           304.0     150.0  3433.0         12.0   70
# 4    17.0          8           302.0     140.0  3449.0         10.5   70
# ..    ...        ...             ...       ...     ...          ...  ...
# 393  27.0          4           140.0      86.0  2790.0         15.6   82
# 394  44.0          4            97.0      52.0  2130.0         24.6   82
# 395  32.0          4           135.0      84.0  2295.0         11.6   82
# 396  28.0          4           120.0      79.0  2625.0         18.6   82
# 397  31.0          4           119.0      82.0  2720.0         19.4   82
#
#      origen                     nombre
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
## Solución
# Ejercicio 4.3.1
# ¿Qué coche pesa más de 5000 kg?
df = pd.DataFrame(mpg_data)
df.loc[df["peso"]>5000, ["nombre","peso"]]
# Out:
#                  nombre    peso
# 44  pontiac safari (sw)  5140.0

# %%
## Solución
# Ejercicio 4.3.2
#idxmax() Return index of first occurrence of maximum over requested axis
#¿Cuál es el número de cilindros más frecuente en los coches que son del año 76?
df_76 = df[df["año"] == 76]
df_76["cilindros"].value_counts().idxmax()
# Out:
# 4

# %%
## Solución
# Ejercicio 4.3.3
#Compara el consumo medio de los coches fabricados en el año 70 con el consumo de los fabricados en el año 79 y calcula la diferencia.
df_70 = df[df["año"] == 70]
df_79 = df[df["año"] == 79]

media_70 = df_70["mpg"].mean()
media_79 = df_79["mpg"].mean()
print("La media de los años 70 es:\n",media_70,"\nLa media de los años 79 es:\n",media_79,"\nLa diferencia es de:\n",media_79-media_70)
# Out:
# La media de los años 70 es:
#  17.689655172413794
# La media de los años 79 es:
#  25.09310344827585
# La diferencia es de:
#  7.403448275862058

# %%
## Solución
# Ejercicio 4.3.4
#Identifica las variables que contienen valores nulos (missing values) en caso de que haya alguna.
df.isnull().sum()
# Out:
# mpg               0
# cilindros         0
# desplazamiento    0
# potencia          6
# peso              0
# aceleración       0
# año               0
# origen            0
# nombre            0
# dtype: int64

# %%
## Solución
# Ejercicio 4.3.5
# Crea un _DataFrame_ con los modelos con 6 o más cilindros, que pesen más de 4000 kg y consumen menos o igual que 10 galón por milla, filtrando el dataset original.
nuevo_df = df[(df["cilindros"] >= 6) & (df["peso"] > 4000) & (df["mpg"] <= 10)]
nuevo_df
# Out:
#      mpg  cilindros  desplazamiento  potencia    peso  aceleración  año  \
# 25  10.0          8           360.0     215.0  4615.0         14.0   70
# 26  10.0          8           307.0     200.0  4376.0         15.0   70
# 28   9.0          8           304.0     193.0  4732.0         18.5   70
#
#     origen     nombre
# 25       1  ford f250
# 26       1  chevy c20
# 28       1   hi 1200d

# %% [markdown]
# ---

# %% [markdown]
# ## Combinando Datasets: Concatenate, Merge y Join

# %% [markdown]
# ### Concatenación de datos

# %% [markdown]
# **Concatenación simple:**
# * _Pandas_ dispone de la función **`pd.concat()`**, que tiene una sintaxis muy similar a **`np.concatenate`**, pero contiene una serie de argumentos adicionales.
# * **`pd.concat()`** se puede usar como una simple concatenación entre objetos de tipo _Serie_ o de tipo _DataFrame_.

# %%
# Nos creamos dos dataframes
df1 = pd.DataFrame(np.array([[1, 2], [3, 4]]),
                   columns=['x', 'y'], index = ['a','b'])

df2 = pd.DataFrame(np.array([[1, 4], [4, 6]]),
                   columns=['x', 'y'], index = ['c','d'])
print(df1)
print("\n",df2)
# Out:
#    x  y
# a  1  2
# b  3  4
#
#     x  y
# c  1  4
# d  4  6

# %%
# Concatenamos (por defecto la concatenación se realiza por filas, si queremos que sea por columnas: axis = 1)
print(pd.concat([df1,df2]))
# Out:
#    x  y
# a  1  2
# b  3  4
# c  1  4
# d  4  6

# %% [markdown]
# **Concatenación mediante _joins_:**
# * En los ejemplos que hemos visto anteriormente hemos realizado la concatenación de dataframes que compartian columnas.
# * En la práctica, los datos que vienen de fuentes diferentes podrían tener diferentes columnas, en estos casos la función **`pd.concat()`** ofrece distintas opciones.

# %%
# Consideremos la concatenación de dos DataFrames, que comparten algunas columnas y otras no
df3 = pd.DataFrame(np.array([[1, 2], [3, 4]]),
                   columns=['x', 'y'], index = ['a','b'])

df4 = pd.DataFrame(np.array([[1, 4], [4, 6]]),
                   columns=['x', 'z'], index = ['c','d'])

print(df3)
print("\n",df4)
# Out:
#    x  y
# a  1  2
# b  3  4
#
#     x  z
# c  1  4
# d  4  6

# %%
pd.concat([df3, df4])
# Out:
#    x    y    z
# a  1  2.0  NaN
# b  3  4.0  NaN
# c  1  NaN  4.0
# d  4  NaN  6.0

# %% [markdown]
# * Por defecto los datos que no machean son rellenados por *NaN*.
# * Para cambiar esto, podemos especificar el parámetro **join**.
# * Por defecto, el **join** es una unión de las columnas de entrada (**join = outer**), pero podemos cambiar esto a una intersección de columnas (**join = inner**).

# %%
# Hacemos un join inner
pd.concat([df3, df4], join = 'inner')
# Out:
#    x
# a  1
# b  3
# c  1
# d  4

# %% [markdown]
# ### Categorías de join
# * La función **`pd.merge()`** implementa varios tipos de joins: el **one-to-one**, **many-to-one** y **many-to-many**.
# * Los tres tipos de join son accesibles **de forma transparente** e idéntica a través de la función **`pd.merge()`**, el tipo de join realizado depende la forma de los datos de entrada.

# %% [markdown]
# * **_One-to-one joins_:**
# Se trata del tipo de join más simple, el cual en muchas ocasiones es muy similar a la concatenación por columna.

# %%
# Creamos dos dataframes, por ejemplo:
df1 = pd.DataFrame({'empleado': ['Borja', 'Jose', 'Lola', 'Sofía'],
'departamento': ['Contabilidad', 'IT', 'IT', 'RRHH']})
df2 = pd.DataFrame({'empleado': ['Lola', 'Borja', 'Jose', 'Sofía'],
'antigüedad': [2021, 2008, 2022, 2014]})

print(df1)
print("\n",df2)
# Out:
#   empleado  departamento
# 0    Borja  Contabilidad
# 1     Jose            IT
# 2     Lola            IT
# 3    Sofía          RRHH
#
#    empleado  antigüedad
# 0     Lola        2021
# 1    Borja        2008
# 2     Jose        2022
# 3    Sofía        2014

# %%
# Probamos la concatenación de los dos DtaFrames para compararlo con el merge
pd.concat([df1, df2])
# Out:
#   empleado  departamento  antigüedad
# 0    Borja  Contabilidad         NaN
# 1     Jose            IT         NaN
# 2     Lola            IT         NaN
# 3    Sofía          RRHH         NaN
# 0     Lola           NaN      2021.0
# 1    Borja           NaN      2008.0
# 2     Jose           NaN      2022.0
# 3    Sofía           NaN      2014.0

# %%
# Hacemos el merge entre los dos cojuntos de datos
df3 = pd.merge(df1, df2)
df3
# Out:
#   empleado  departamento  antigüedad
# 0    Borja  Contabilidad        2008
# 1     Jose            IT        2022
# 2     Lola            IT        2021
# 3    Sofía          RRHH        2014

# %% [markdown]
# La función `pd.merge()` es capaz de reconocer que ambos conjuntos de datos comparten la columna **empleado**, y de forma automática realiza la unión por esta columna. Es decir, usa dicha columna como clave. El resultado de la unión es un nuevo DataFrame que contiene la info de las dos entradas.
# Además la función `pd.merge()` no mantiene el índice, salvo que la unión se haga explícitamente por el índice.

# %% [markdown]
# * **_Many-to-one joins_:** Se tratan de joins en los cuales una de las dos columnas clave contiene entradas duplicadas. En este caso el DataFrame resultante mantendrá estos valores duplicados.

# %%
# Declaramos un nuevo DataFrame
df4 = pd.DataFrame({'departamento': ['Contabilidad', 'IT', 'RRHH'],'supervisor': ['Celia', 'Gabriel', 'Sergio']})
df4
# Out:
#    departamento supervisor
# 0  Contabilidad      Celia
# 1            IT    Gabriel
# 2          RRHH     Sergio

# %%
# Hacemos el merge de los dos últimos DataFrames
pd.merge(df3, df4)
# Out:
#   empleado  departamento  antigüedad supervisor
# 0    Borja  Contabilidad        2008      Celia
# 1     Jose            IT        2022    Gabriel
# 2     Lola            IT        2021    Gabriel
# 3    Sofía          RRHH        2014     Sergio

# %% [markdown]
# * **_Many-to-many joins_:**
# Si las dos columnas clave, contienen valores duplicados, entonces el resultado es un _many-to-many_ merge.

# %%
df5 = pd.DataFrame({'departamento': ['Contabilidad', 'Contabilidad','IT', 'IT', 'RRHH', 'RRHH'],
                    'competencias': ['Matemáticas', 'Economía', 'programación', 'Cloud','Excel', 'Comunicación']})
print(df1)
print("\n",df5)
# Out:
#   empleado  departamento
# 0    Borja  Contabilidad
# 1     Jose            IT
# 2     Lola            IT
# 3    Sofía          RRHH
#
#     departamento  competencias
# 0  Contabilidad   Matemáticas
# 1  Contabilidad      Economía
# 2            IT  programación
# 3            IT         Cloud
# 4          RRHH         Excel
# 5          RRHH  Comunicación

# %%
# Hacemos el merge
pd.merge(df1,df5)
# Out:
#   empleado  departamento  competencias
# 0    Borja  Contabilidad   Matemáticas
# 1    Borja  Contabilidad      Economía
# 2     Jose            IT  programación
# 3     Jose            IT         Cloud
# 4     Lola            IT  programación
# 5     Lola            IT         Cloud
# 6    Sofía          RRHH         Excel
# 7    Sofía          RRHH  Comunicación

# %% [markdown]
# **Especificando la clave para el Merge:**
# * Parámetro **`on`**: podemos especificar de forma explícita el **nombre de la columna** que queremos que se utilice como clave. Este valor puede tomar el nombre de la columna o bien una lista de columnas.

# %%
print(df1)
print("\n",df2)
# Out:
#   empleado  departamento
# 0    Borja  Contabilidad
# 1     Jose            IT
# 2     Lola            IT
# 3    Sofía          RRHH
#
#    empleado  antigüedad
# 0     Lola        2021
# 1    Borja        2008
# 2     Jose        2022
# 3    Sofía        2014

# %%
# Mergeamos los dos DataFrames indicando la columna clave
pd.merge(df1, df2, on = 'empleado')
# Out:
#   empleado  departamento  antigüedad
# 0    Borja  Contabilidad        2008
# 1     Jose            IT        2022
# 2     Lola            IT        2021
# 3    Sofía          RRHH        2014

# %% [markdown]
# **Especificando operaciones aritméticas en joins**

# %% [markdown]
# * Por defecto la función **`pd.merge()`** realiza lo que se conoce como **inner join**, es decir, retorna la intersección entre ambos conjuntos de datos.
# * Podemos especificar el tipo mediante el parámetro **how**.
# * Los valores que puede tomar el argumento **how** son: **`'inner'`** (intersección de datos), **`'outer'`** (unión de datos), **`'left'`** y **`'right'`**.
# * Los valores **left_join** y **right_join** nos retornan las uniones de los dataframes correspondientes en función de sus posiciones. Es decir, si hacemos un **left_join** mantendremos los valores de la tabla de la izquierda más la unión de estos valores con la tabla de la derecha.
# * Los valores perdidos son rellenados como _NaN_.

# %%
# Supongamos el siguiente conjunto de datos
df6 = pd.DataFrame({'nombre': ['Pedro', 'Carlos', 'María'],'comida': ['carne', 'embutido', 'pescado']}, columns=['nombre', 'comida'])
df7 = pd.DataFrame({'nombre': ['María', 'Javier'],'bebida': ['sidra', 'cerveza']},columns=['nombre', 'bebida'])
print(df6)
print("\n",df7)
# Out:
#    nombre    comida
# 0   Pedro     carne
# 1  Carlos  embutido
# 2   María   pescado
#
#     nombre   bebida
# 0   María    sidra
# 1  Javier  cerveza

# %%
# Maergear los DataFrames de manera por defecto
pd.merge(df6, df7)
# Out:
#   nombre   comida bebida
# 0  María  pescado  sidra

# %%
# Hacemos el merge con outr (la unión)
pd.merge(df6, df7, how = 'outer')
# Out:
#    nombre    comida   bebida
# 0   Pedro     carne      NaN
# 1  Carlos  embutido      NaN
# 2   María   pescado    sidra
# 3  Javier       NaN  cerveza

# %%
# Hacemos el merge con left_join
pd.merge(df6, df7, how = 'left')
# Out:
#    nombre    comida bebida
# 0   Pedro     carne    NaN
# 1  Carlos  embutido    NaN
# 2   María   pescado  sidra

# %%
# Hacemos el merge con righ_join
pd.merge(df6, df7, how = 'right')
# Out:
#    nombre   comida   bebida
# 0   María  pescado    sidra
# 1  Javier      NaN  cerveza

# %% [markdown]
# ## Groupby: Split, Apply, Combine
# Si bien las agregaciones simples pueden darle un significado a nuestros datos, en determinadas situaciones es posible que queramos realizar estas agregaciones a partir de una serie de índices o etiquetas: esto puede ser realizado mediane la operación **groupby**.

# %% [markdown]
# * El paso **split** implica dividir y agrupar un DataFrame, según el valor de la clave especificada.
#
# * El paso **apply** implica aplicar una función usualmente de agregación, transformación o filtrado a cada uno de los grupos individuales.
#
# * El paso **combine** finalmente unifica los resultados en un solo array o dataframe.

# %%
# Generamos un conjunto de datos tipo DataFrame (con los índices por defecto)
df = pd.DataFrame({'key': ['A', 'B', 'C', 'B', 'A', 'B', 'C'],
                   'data': range(7)}, columns=['key', 'data'])

df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   B     3
# 4   A     4
# 5   B     5
# 6   C     6

# %%
df.groupby('key')

# %% [markdown]
# * La potencia de la operación groupby es que permite al usuario ignorar como se realizan todas estas operaciones por detrás.
# * Podemos calcular el conjunto de operaciones split, apply y combine simplemente haciendo uso de la función **groupby** pasándole la clave por la cual deseamos realizar esto.
# * Podemos notar que no retorna un objeto de tipo DataFrame, sino que retorna un objeto de tipo **DataFrameGroupBy**. Este objeto, se trata de un objeto que **está preparado** para atacar a los grupos , pero **no realiza un cálculo real** hasta que no se realice algún tipo de agregación.

# %% [markdown]
# Vamos a intentar sumar todos los datos de _A_, todos los de _B_ y todos los de _C_. Sin hacer uso de **`groupby()`**:

# %% [markdown]
# 1. **_Split_**

# %%
# Filtrar los registros de A
df_A = df[df['key']=='A']
df_A
# Out:
#   key  data
# 0   A     0
# 4   A     4

# %%
# Filtrar los registros de B
df_B = df[df['key']=='B']
df_B
# Out:
#   key  data
# 1   B     1
# 3   B     3
# 5   B     5

# %%
# Filtrar los registros de C
df_C = df[df['key']=='C']
df_C
# Out:
#   key  data
# 2   C     2
# 6   C     6

# %% [markdown]
# 2. **_Apply_**

# %%
# Sumamos los de A 
sum_A = df_A['data'].sum()
sum_A
# Out:
# 4

# %%
# Sumamos los de B 
sum_B = df_B['data'].sum()
sum_B
# Out:
# 9

# %%
# Sumamos los de C
sum_C = df_C['data'].sum()
sum_C
# Out:
# 8

# %% [markdown]
# 3. **Combine**

# %%
# Construir el DataFrame con los resultados obtenidos de las sumas por separado
d = {'key': ['A', 'B', 'C'],
    'suma': [sum_A, sum_B, sum_C]}

df_sumas = pd.DataFrame(d)
df_sumas
# Out:
#   key  suma
# 0   A     4
# 1   B     9
# 2   C     8

# %% [markdown]
# Vemos que esta forma de sumar los datos de _A_, _B_ y _C_es bastante tediosa.
# Sin embargo, podemos realizar la misma operación con una sola línea de código usando el método **`groupy()`**.

# %%
# Aplicamos la agregación de sumatorio
df.groupby('key').sum()
# Out:
#      data
# key
# A       4
# B       9
# C       8

# %%
# Aplicamos la agregación de mínimo 
df.groupby('key').min()
# Out:
#      data
# key
# A       0
# B       1
# C       2

# %%
# Aplicamos la agregación de conteo para cada grupo
df.groupby('key').count()
# Out:
#      data
# key
# A       2
# B       3
# C       2

# %% [markdown]
# * El objeto de tipo _GroupBy_ se trata de un objeto muy **flexible** que nos permite realizar una serie de operaciones bastantes complejas de una forma más sencilla.
#
# * Dado un objeto de tipo *Groupby* podemos hacer uso de los distintos métodos vistos para cada uno de los grupos por ejemplo podemos aplicar el método `describe()`.

# %%
df.groupby('key').describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/pablo/BD/analisis_datos_python_Elias/sesion_4/Sesion4-Bloque1-Tratamiento-Datos-DataFrames-Series-BigData+.ipynb Celda 188 line 1
# ----> <a href='vscode-notebook-cell:/Users/pablo/BD/analisis_datos_python_Elias/sesion_4/Sesion4-Bloque1-Tratamiento-Datos-DataFrames-Series-BigData%2B.ipynb#Y355sZmlsZQ%3D%3D?line=0'>1</a> df.groupby('key').describe()
#       <a href='vscode-notebook-cell:/Users/pablo/BD/analisis_datos_python_Elias/sesion_4/Sesion4-Bloque1-Tratamiento-Datos-DataFrames-Series-BigData%2B.ipynb#Y355sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'key'

# %% [markdown]
# **Agregación:**
# Hasta ahora estamos familiarizados con las agregaciones **`sum()`**, **`mean()`** etc para la función _GroupBy_. La función **`aggregate()`** (o simplemente **`agg()`**) nos permite una mayor flexibilidad. Esta función puede tomar una lista de agregaciones y computar todas a la vez.

# %%
# Pasamoa la función min mesiante aggregate
df.groupby('key').agg(min)
# Out:
#      data
# key
# A       0
# B       1
# C       2

# %%
# Aplicamos de golpe una lista de funciones con aggregate
df.groupby('key').aggregate(['min', np.median, max])
# Out:
#     data
#      min median max
# key
# A      0    2.0   4
# B      1    3.0   5
# C      2    4.0   6

# %%
# Definir una función que saca el número total de bytes consumido para cada grupo y aplicarlo mediante aggregate()
num_bytes = lambda x: x.nbytes
df.groupby('key').aggregate(num_bytes)
# Out:
#      data
# key
# A      16
# B      24
# C      16

# %% [markdown]
# **Transformación:**
# Mientras que la agregación retorna una versión reducida de los datos, **`.transform()`** retorna una versión completa de los datos transformados. Por lo tanto, la **salida** tras aplicar una transformación **es de igual tamaño** que los datos de **entrada**.

# %%
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   B     3
# 4   A     4
# 5   B     5
# 6   C     6

# %%
df.groupby('key').aggregate(sum)
# Out:
#      data
# key
# A       4
# B       9
# C       8

# %%
df.groupby('key').transform(sum)
# Out:
#    data
# 0     4
# 1     9
# 2     8
# 3     9
# 4     4
# 5     9
# 6     8

# %%
df.groupby('key').transform(max)
# Out:
#    data
# 0     4
# 1     5
# 2     6
# 3     5
# 4     4
# 5     5
# 6     6

# %% [markdown]
# El método **`transform()`** sirve sobre todo a la hora de **crear nuevas variables (columnas)** con la salida de _groupby_.

# %%
# Añadimos una nueva columna que indique el valor máximo de todos los valores por grupo
df["max_grupo"] = df.groupby(['key']).transform(max) 
df
# Out:
#   key  data  max_grupo
# 0   A     0          4
# 1   B     1          5
# 2   C     2          6
# 3   B     3          5
# 4   A     4          4
# 5   B     5          5
# 6   C     6          6

# %% [markdown]
# ### **`Ejercicio 4.4`**
#
# **`4.4.1`** A continuación vienen dos tablas que corresponden a número de aportaciones (_pull request_) de cada desarrollador de un equipo de análisis de datos en diferentes versiones liberadas (_Released versions_) de una aplicación corporativa . Concatena de forma básica los dos _DataFrames_ y calcula el número de filas de la tabla concatenada.
#
# **`4.4.2`** Realiza un merge con la unión de los dos _DataFrames_ y calcula el número de filas de la tabla resultante.
#
# **`4.4.3`** Realiza un merge con la intersección de los dos _DataFrames_ y calcula el número de filas de la tabla resultante.
#
# **`4.4.4`** Volviendo al dataset de "**Auto-MPG**" usado en el `ejercicio 4.3`, genera de nuevo el DataFrame y después saca las medias de cada variable por año.
#
# **`4.4.5`** Dibuja la evolución del peso medio de los coches a lo largo de los años, y analiza su tendencia.

# %%
### Ejercicio 4.4.1

analistas1 = pd.DataFrame([["Sara",4,3,8],["Manuel",2,7,3],["Pablo",2,6,4],["Antonio",1,9,6]], columns=["Name","B","C", "D"])

analistas2 = pd.DataFrame([["Claudia",6,3],["Luis",10,7],["Sara",7,11],["Pablo",12,14]], columns=["Name","F","G"])

display(analistas1)
display(analistas2)
# Out:
#       Name  B  C  D
# 0     Sara  4  3  8
# 1   Manuel  2  7  3
# 2    Pablo  2  6  4
# 3  Antonio  1  9  6
#       Name   F   G
# 0  Claudia   6   3
# 1     Luis  10   7
# 2     Sara   7  11
# 3    Pablo  12  14

# %%
## Solución
# Ejercicio 4.4.1
# A continuación vienen dos tablas que corresponden a número de aportaciones (_pull request_) de cada desarrollador de un equipo de análisis de datos en diferentes versiones liberadas (_Released versions_) de una aplicación corporativa . Concatena de forma básica los dos _DataFrames_ y calcula el número de filas de la tabla concatenada.
df_concat = pd.concat([analistas1,analistas2])
print(df_concat)
df_concat.shape[0]
# Out:
#       Name    B    C    D     F     G
# 0     Sara  4.0  3.0  8.0   NaN   NaN
# 1   Manuel  2.0  7.0  3.0   NaN   NaN
# 2    Pablo  2.0  6.0  4.0   NaN   NaN
# 3  Antonio  1.0  9.0  6.0   NaN   NaN
# 0  Claudia  NaN  NaN  NaN   6.0   3.0
# 1     Luis  NaN  NaN  NaN  10.0   7.0
# 2     Sara  NaN  NaN  NaN   7.0  11.0
# 3    Pablo  NaN  NaN  NaN  12.0  14.0
# 8

# %%
## Solución
# Ejercicio 4.4.2
# Realiza un merge con la unión de los dos _DataFrames_ y calcula el número de filas de la tabla resultante.
df_merge = pd.merge(analistas1,analistas2, how="outer")
print(df_merge)
df_merge.shape[0]
# Out:
#       Name    B    C    D     F     G
# 0     Sara  4.0  3.0  8.0   7.0  11.0
# 1   Manuel  2.0  7.0  3.0   NaN   NaN
# 2    Pablo  2.0  6.0  4.0  12.0  14.0
# 3  Antonio  1.0  9.0  6.0   NaN   NaN
# 4  Claudia  NaN  NaN  NaN   6.0   3.0
# 5     Luis  NaN  NaN  NaN  10.0   7.0
# 6

# %%
## Solución
# Ejercicio 4.4.3
# Realiza un merge con la intersección de los dos _DataFrames_ y calcula el número de filas de la tabla resultante.
df_merge_interseccion = pd.merge(analistas1,analistas2, how="inner")
print(df_merge_interseccion)
df_merge_interseccion.shape[0]
# Out:
#     Name  B  C  D   F   G
# 0   Sara  4  3  8   7  11
# 1  Pablo  2  6  4  12  14
# 2

# %%
### Ejercicio 4.4.4

path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, delim_whitespace=True, header=None,
            names = ['mpg', 'cilindros', 'desplazamiento','potencia',
            'peso', 'aceleración', 'año', 'origen', 'nombre'],
            na_values='?')

# El DataFrame que se carga
mpg_data
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleración  año  \
# 0    18.0          8           307.0     130.0  3504.0         12.0   70
# 1    15.0          8           350.0     165.0  3693.0         11.5   70
# 2    18.0          8           318.0     150.0  3436.0         11.0   70
# 3    16.0          8           304.0     150.0  3433.0         12.0   70
# 4    17.0          8           302.0     140.0  3449.0         10.5   70
# ..    ...        ...             ...       ...     ...          ...  ...
# 393  27.0          4           140.0      86.0  2790.0         15.6   82
# 394  44.0          4            97.0      52.0  2130.0         24.6   82
# 395  32.0          4           135.0      84.0  2295.0         11.6   82
# 396  28.0          4           120.0      79.0  2625.0         18.6   82
# 397  31.0          4           119.0      82.0  2720.0         19.4   82
#
#      origen                     nombre
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
## Solución
# Ejercicio 4.4.4
# Volviendo al dataset de "**Auto-MPG**" usado en el `ejercicio 4.3`, genera de nuevo el DataFrame y después saca las medias de cada variable por año. 
df = pd.DataFrame(mpg_data)
df.groupby('año').mean()
# Out:
# /var/folders/j3/km7zm3k92gb35xzx0v7c_5pm0000gn/T/ipykernel_3000/3348597029.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('año').mean()
#            mpg  cilindros  desplazamiento    potencia         peso  \
# año
# 70   17.689655   6.758621      281.413793  147.827586  3372.793103
# 71   21.250000   5.571429      209.750000  107.037037  2995.428571
# 72   18.714286   5.821429      218.375000  120.178571  3237.714286
# 73   17.100000   6.375000      256.875000  130.475000  3419.025000
# 74   22.703704   5.259259      171.740741   94.230769  2877.925926
# 75   20.266667   5.600000      205.533333  101.066667  3176.800000
# 76   21.573529   5.647059      197.794118  101.117647  3078.735294
# 77   23.375000   5.464286      191.392857  105.071429  2997.357143
# 78   24.061111   5.361111      177.805556   99.694444  2861.805556
# 79   25.093103   5.827586      206.689655  101.206897  3055.344828
# 80   33.696552   4.137931      115.827586   77.481481  2436.655172
# 81   30.334483   4.620690      135.310345   81.035714  2522.931034
# 82   31.709677   4.193548      128.870968   81.466667  2453.548387
#
#      aceleración    origen
# año
# 70     12.948276  1.310345
# 71     15.142857  1.428571
# 72     15.125000  1.535714
# 73     14.312500  1.375000
# 74     16.203704  1.666667
# 75     16.050000  1.466667
# 76     15.941176  1.470588
# 77     15.435714  1.571429
# 78     15.805556  1.611111
# 79     15.813793  1.275862
# 80     16.934483  2.206897
# 81     16.306897  1.965517
# 82     16.638710  1.645161

# %%
## Solución
# Ejercicio 4.4.5
# Dibuja la evolución del peso medio de los coches a lo largo de los años, y analiza su tendencia.
df.groupby('año')["peso"].mean().plot()
#En el gráfico podemos observar que el peso de los coches va dismunuyendo conforme el tiempo avanza como es lógico.
# Out:
# <Axes: xlabel='año'>
