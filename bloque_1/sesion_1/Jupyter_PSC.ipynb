# %%
x = "str"
y = 1
z = 1.1
d = False

print("La variable x es de tipo "+ str(type(x)) + " y contiene "+ x)
print("La variable y es de tipo "+ str(type(y)) + " y contiene "+ str(y))
print("La variable z es de tipo "+ str(type(z)) + " y contiene "+ str(z))
print("La variable d es de tipo "+ str(type(d)) + " y contiene "+ str(d))
# Out:
# La variable x es de tipo <class 'str'> y contiene str
# La variable y es de tipo <class 'int'> y contiene 1
# La variable z es de tipo <class 'float'> y contiene 1.1
# La variable d es de tipo <class 'bool'> y contiene False

# %% [markdown]
# 5. Instalar la librería **shap** mediante la consola de **Anaconda Prompt**, sacar un recorte de la consola y guardar el pantallazo en una celda del notebook ***Jupyter_<iniciales_del_alumn@>.ipynb***
#
# <img src="/Users/pablo/BD/analisis de datos python/sesion_1/jupyter_PSC.png">
#
#
#
# (base)  pablo@MacBook-Pro-de-Pablo  ~  conda install -c conda-forge shap
# Collecting package metadata (current_repodata.json): | DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/osx-arm64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 200 None
# - DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/osx-arm64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/current_repodata.json HTTP/1.1" 200 None
# done
# Solving environment: done
#
#  Package Plan ##
#
#   environment location: /Users/pablo/anaconda3
#
#   added / updated specs:
#     - shap
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       hf0a4a13_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     conda-23.7.3               |  py311hca03da5_0         1.3 MB
#     conda-content-trust-0.2.0  |     pyhd8ed1ab_0          57 KB  conda-forge
#     openssl-1.1.1v             |       h53f4e23_0         1.6 MB  conda-forge
#     shap-0.42.1                |  py311h7aedaa7_0         743 KB
#     slicer-0.0.7               |     pyhd8ed1ab_0          16 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   shap               pkgs/main/osx-arm64::shap-0.42.1-py311h7aedaa7_0
#   slicer             conda-forge/noarch::slicer-0.0.7-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.05.30~ --> conda-forge::ca-certificates-2023.7.22-hf0a4a13_0
#   conda                              23.7.2-py311hca03da5_0 --> 23.7.3-py311hca03da5_0
#   conda-content-tru~ pkgs/main::conda-content-trust-0.1.1-~ --> conda-forge::conda-content-trust-0.2.0-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1u-h1a28f6b_0 --> conda-forge::openssl-1.1.1v-h53f4e23_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/osx-arm64::certifi-2023.7.2~ --> conda-forge/noarch::certifi-2023.7.22-pyhd8ed1ab_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# conda-content-trust- | 57 KB     |                                                                                                                                                                                                                 |   0%
# shap-0.42.1          | 743 KB    |                                                                                                                                                                                                                 |   0%
# openssl-1.1.1v       | 1.6 MB    |                                                                                                                                                                                                                 |   0%
# conda-23.7.3         | 1.3 MB    |                                                                                                                                                                                                                 |   0%DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443                                                                                                                                                               |   0%
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443                                                                                                                                                             |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/conda-23.7.3-py311hca03da5_0.conda HTTP/1.1" 200 1408914
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443                                                                                                                                                                    DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/osx-arm64/openssl-1.1.1v-h53f4e23_0.conda HTTP/1.1" 200 1654221                                                                                                       |   0%
#                                                                                                                                                                                                                                                          DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/conda-content-trust-0.2.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 58873                                                                                               |   8%
# conda-content-trust- | 57 KB     | #########################################################6                                                                                                                                                      |  28% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/slicer-0.0.7-pyhd8ed1ab_0.tar.bz2 HTTP/1.1" 200 16814
# conda-content-trust- | 57 KB     | ############################################################################################################################################################################################################### | 100%DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/shap-0.42.1-py311h7aedaa7_0.conda HTTP/1.1" 200 760931
# openssl-1.1.1v       | 1.6 MB    | ##################4                                                                                                                                                                                             |   9%DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/osx-arm64/ca-certificates-2023.7.22-hf0a4a13_0.conda HTTP/1.1" 200 149918                                                                                             |   2%
# slicer-0.0.7         | 16 KB     | ############################################################################################################################################################################################################### | 100%DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/certifi-2023.7.22-pyhd8ed1ab_0.conda HTTP/1.1" 200 153791                                                                                                      |  17%
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
