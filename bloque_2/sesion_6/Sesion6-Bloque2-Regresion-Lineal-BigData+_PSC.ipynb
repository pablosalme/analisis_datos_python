# %% [markdown]
# # Módulo 1: Análisis de datos en el ecosistema Python

# %% [markdown]
# ### Sesión (6)

# %% [markdown]
# **09/10/2023**

# %% [markdown]
# # 1. Aprendizaje de máquina (automático):   **Machine Learning**

# %% [markdown]
# El **aprendizaje automático** es una rama de la **inteligencia artificial** basada en el concepto de que las máquinas pueden aprender de datos, detectar patrones y tomar decisiones casi sin la intervención humana. El **machine learning** es un método de tratamiento y análisis de datos que **automatiza** la creación de **modelos analíticos**.

# %% [markdown]
# ![machine-learning-types.jpg](attachment:machine-learning-types.jpg)

# %% [markdown]
# ## 1.1  Aprendizaje supervisado
#
# Este algoritmo consta de una **variable objetivo** (variable dependiente) que se va a predecir a partir de un conjunto dado de **predictores** (variables independientes).
#
# Usando este conjunto de variables, generamos una función que asigna entradas a salidas. El proceso de aprendizaje de este tipo de algoritmos continúa hasta que el modelo alcanza un nivel deseado de precisión tanto en los datos de entrenamiento (_training_) como en los conjuntos de datos de prueba (_test_).

# %% [markdown]
# ![regression-vs-classification-in-machine-learning.png](attachment:regression-vs-classification-in-machine-learning.png)

# %% [markdown]
# * ### Clasificación:
#     * El output tiene **etiquetas** predefinidas con valores **discretos**
#     * Usamos clasificación cuando la variable objetivo es **categórica** (grupos y clases)
#     * ***Tipos de algoritmo de clasificación:***
#         * Logistic Regression (variables binarias)
#         * Decision Tree (árbol de decisión)
#         * Random Forest (conjunto de árboles de decisión)
#         * Naive Bayes Clasificador
#         * SVM (Support Vector Machines)
#         * ANN (Artificial Neural Networks)
# * ### Regresión:
#     * Usamos regresión cuando la variable output es un valor **numérico continuo**.
#     * ***Tipos de alrgotimo de regresión:***
#         * Regresión Lineal ( simple con una variable independiente o múltiple con varios output)
#         * Polinomial
#         * Ridge, Lasso, ElasticNet (cuando las variables independientes están altamente correlacionadas)
#         * Decision Tree Regression
#         * Random Forest Regression
#         * Neural Network Regression

# %% [markdown]
# ## 1.2. Aprendizaje no supervisado
#
# En este tipo de algoritmos, no tenemos **ningún objetivo o variable de resultado** para predecir/estimar. Se suele utilizar para **agrupar** la población en diferentes grupos, por ejemplo para segmentar a los clientes en diferentes grupos para una intervención específica.

# %% [markdown]
# ![Examples-of-Supervised-Learning-Linear-Regression-and-Unsupervised-Learning_W640.jpg](attachment:Examples-of-Supervised-Learning-Linear-Regression-and-Unsupervised-Learning_W640.jpg)

# %% [markdown]
# ## 1.3. Aprendizaje por refuerzo
#
# Con este algoritmo, la máquina está entrenada para tomar decisiones específicas. Funciona de esta manera: la máquina está expuesta a un **entorno** en el que **entrena a sí misma** continuamente usando **prueba y error**. Esta máquina aprende de la experiencia pasada e intenta capturar el mejor conocimiento posible para las decisiones más precisas.

# %% [markdown]
# ![aprendizaje-por-refuerzo-automatico-machine-learning-inteligencia-artificial.png](attachment:aprendizaje-por-refuerzo-automatico-machine-learning-inteligencia-artificial.png)

# %% [markdown]
# ## 1.4. Flujo del proceso de modelado
#
# Los procesos que se realizan para desarrollar un modelo con las técnicas de machine learning tienen un **ciclo de vida** que describe las fases principales por las que normalmente psasn los proyectos de **Data Science** o análisis de datos:
#  * **1. Definición del problema**
#      * Visión de negocio
#      * Análisis preliminar
#  * **2. Obtención de datos**
#      * Fuentes de datos
#      * Conexiones y consultas a bases de datos
#  * **3. Preparación y tratamiento de datos**
#      * Campos vacios (valores perdidos)
#      * Campos inválidos (valores negativos, fuera del rango permitido...)
#      * Outliers (valores atípicos)
#      * Datos catégoricos (campos no numéricos)
#      * Datos multiescalas (normalización y estandarización de datos)
#  * **4. Dividir los conjuntos de datos**
#      * Datos de entrenamiento (Training)
#      * Datos de prueba (Test)
#  * **5. Construir el modelo**
#      * Seleccionar el algoritmo adecuado
#      * Ajustar el modelo
#      * Optimizar los hiper-parametros
#  * **6. Análisis de errores y reentrenamineto**
#  * **7. Productivizar e integrar el modelo en el sistema**
#  * **8. Monitorizar, mantener y mejorar el proceso**

# %% [markdown]
# ![Process-Flow2.png](attachment:Process-Flow2.png)

# %% [markdown]
# # 2.  Linear Regression (regresión lineal)
#
# La regresión lineal es una técnica paramétrica de machine learning. Con **paramétrica** queremos decir que incluso antes de mirar a los datos, ya sabemos cuántos parámetros (o coeficientes) vamos a necesitar.
#
# Se utiliza para estimar valores reales (costo de las casas, número de llamadas, ventas totales, etc.) en función de la variable (regresión lineal simple) o las variables (regresión lineal múltiple) continuas.
#
# El modelo de regresión trata de **establecer una relación entre variables independientes y dependientes ajustando una mejor "línea"**. Esta línea de mejor ajuste se conoce como ***línea de regresión***.
#
# Es decir, el aprendizaje consiste en **encontrar cuáles son los mejores parámetros (coeficientes)** para los datos que tengamos. Los mejores coeficientes serán los que minimicen alguna medida de error.

# %% [markdown]
# ## 2.1 Regresión lineal simple

# %% [markdown]
# Cuando sólamente tenemos una variable, la **ecuación para la regresión lineal** está representada por una ecuación:  $Y = a X + b$.
# En esta ecuación:
# * `Y` - Variable dependiente
# * `a` - Pendiente
# * `X` - Variable independiente (predictor)
# * `b` - Intercept ( sería el corte con el origen en la recta de regresión lineal simple)
#
# Nuestro **objetivo** será determinar el valor de los coeficientes `a` y `b` que proporcionan el error mínimo para el conjunto de datos dado. Para **minimizar el error** necesitamos una forma de calcular el error en primer lugar.
#
# Veamos todos los pasos de un modelo de regresión lineal simple con un ejemplo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ejemplo regresión lineal simple - [Fisher’s Iris dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * El conjunto de datos de flores de Iris  es un conjunto de datos multivariante introducido por el estadístico y biólogo británico **Ronald Fisher**
# * El conjunto de datos consta de **50 muestras** de cada una de **las tres especies de Iris**:
#     * Iris **setosa**
#     * Iris **virginica**
#     * Iris **versicolor**
# * Se midieron cuatro características de cada muestra:
#     * el **largo** de los **sépalos**, en centímetros.
#     * el **ancho** de los **sépalos**, en centímetros.
#     * el **largo** de los **pétalos**, en centímetros.
#     * el **ancho** de los **pétalos**, en centímetros.
# * Basado en la combinación de estas cuatro características, Fisher desarrolló un modelo discriminante lineal para **distinguir las especies** entre sí.

# %% [markdown]
# ### **Análisis preliminar (descriptivo):** Importar y pre-procesar los datos para el modelo

# %%
# importamos las librerías necesarias 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Modificamos los parámetros de los gráficos en matplotlib
from matplotlib.pyplot import rcParams

rcParams['figure.figsize'] = 12, 6 # el primer dígito es el ancho y el segundo el alto
rcParams["font.weight"] = "bold"
rcParams["font.size"] = 10
rcParams["axes.labelweight"] = "bold"

# %% [markdown]
# Importamos los datos del ejemplo Fisher’s Iris data set

# %%
from sklearn.datasets import load_iris

# Construimos un dataframe con los datos medidos 
dataset = pd.DataFrame(load_iris()["data"],columns=load_iris()["feature_names"])

# Añadimos la especie como etiqueta
dataset["label"] = load_iris()["target_names"][load_iris()["target"]]

dataset
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          label
# 0       setosa
# ...

# %%
# La info útil sobre los datos en general 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   label              150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Podemos extraer las estadísticas principales de los datos
dataset.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# Para hacernos una idea de como están distribuidos los datos podemos visualizar estos usando **Pairplot** como ya vimos en la sesión anterior. Pairplot representa sobre todo **la relación entre las variables del dataset**.

# %%
sns.pairplot(dataset, hue="label", height=3)
plt.show()
# Out:
# /Users/pablo/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Tratamiento y filtrado de datos

# %%
# Explorar si existen valores nulos
dataset.isnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
#      label
# 0    False
# ...

# %%
# Conteo de valores perdidos/faltantes  
dataset.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# label                0
# dtype: int64

# %%
# Quitar los posibles valores perdidos
dataset = dataset.dropna()
dataset
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          label
# 0       setosa
# ...

# %% [markdown]
# ### Filtrar Outliers (valores atípicos)
#
# Uno de los métodos para identificar los outliers es analizar la **distancia intercuartil** representada en un diagrama de cajas (**boxplot**).

# %% [markdown]
# ![1_2c21SkzJMf3frPXPAR_gZA.png](attachment:1_2c21SkzJMf3frPXPAR_gZA.png)

# %%
# Graficar la distribución y los valores demostrados en el diagrama de caja
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot(y="petal width (cm)", x= "label", data=dataset,  orient='v' , ax=axes[0, 0])
sns.boxplot(y="petal length (cm)", x= "label", data=dataset,  orient='v' , ax=axes[0, 1])
sns.boxplot(y="sepal width (cm)", x= "label", data=dataset,  orient='v' , ax=axes[1, 0])
sns.boxplot(y="sepal length (cm)", x= "label", data=dataset,  orient='v' , ax=axes[1, 1])
plt.show()

# %% [markdown]
# Se ve que por ejemplo para la especie setosa existen distintos valores atípicos. Analizamos los outliers para el largo de pétalola en esta especie:

# %%
# Filtrat el dataset para quedarnos solamente con los datos de la especie "setosa"
dataset_setosa = dataset[dataset['label']=="setosa"]

# Visualizar los valores del largo del pétalo y su diagrama de cajas
fig, axes = plt.subplots(2,1)
sns.swarmplot(x=dataset_setosa['petal length (cm)'], ax=axes[0])
sns.boxplot(x=dataset_setosa['petal length (cm)'], ax=axes[1])
plt.show()

# %%
# Filtrar los valores atípicos para la especie "setosa" basada en el rango intercuartil
Q1 = dataset_setosa['petal length (cm)'].quantile(0.25)
Q3 = dataset_setosa['petal length (cm)'].quantile(0.75)

# IQR es el rango intercuartil 
IQR = Q3 - Q1    

# Limites permitidos para los datos del largo del pétalo
lim_inf = Q1 - 1.5 * IQR
lim_sup = Q3 + 1.5 *IQR

# Crear la máscara
filtro_oulier = (dataset_setosa['petal length (cm)'] < lim_inf) | (dataset_setosa['petal length (cm)'] > lim_sup)

# Filtramos el dataset aplicando la máscara
dataset_setosa[filtro_oulier]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 13                4.3               3.0                1.1               0.1
# 22                4.6               3.6                1.0               0.2
# 24                4.8               3.4                1.9               0.2
# 44                5.1               3.8                1.9               0.4
#
#      label
# 13  setosa
# 22  setosa
# 24  setosa
# 44  setosa

# %%
# Podemos identificar los outliers por sus índices 
dataset_setosa[filtro_oulier].index
# Out:
# Index([13, 22, 24, 44], dtype='int64')

# %%
# Quitar los outliers del dataset
outliers_ind = dataset_setosa.loc[filtro_oulier].index
dataset = dataset.drop(index=outliers_ind).reset_index(drop=True)
dataset
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 141                6.7               3.0                5.2               2.3
# 142                6.3               2.5                5.0               1.9
# 143                6.5               3.0                5.2               2.0
# 144                6.2               3.4                5.4               2.3
# 145                5.9               3.0                5.1               1.8
#
#          label
# 0       setosa
# ...

# %% [markdown]
# Es fundamental tener en cuenta que solamente las medidas numéricas pueden formar un modelo

# %%
# Quedarnos solamente con las columnas numéricas
dataset_num = dataset.drop("label", axis=1)
dataset_num
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 141                6.7               3.0                5.2               2.3
# 142                6.3               2.5                5.0               1.9
# 143                6.5               3.0                5.2               2.0
# 144                6.2               3.4                5.4               2.3
# 145                5.9               3.0                5.1               1.8
#
# [146 rows x 4 columns]

# %% [markdown]
# ### Normalizar los datos
# Por normalizar nos referimos a **poner los datos en una escala similar** como de `[0,1]`, que es un caso especial de la escalación llamado **“min-max”**.

# %% [markdown]
# ![0_pVqd_DjfuvdUN5mc.png](attachment:0_pVqd_DjfuvdUN5mc.png)

# %%
# importar los objetos necesarios de la librería sklearn
from sklearn.preprocessing import MinMaxScaler

# declarar el tipo de escalamiento y aplicarlo al conjunto de datos
escalado = MinMaxScaler().fit(dataset_num)
dataset_normal = escalado.transform(dataset_num)

# %%
# El dataset original sigue como antes
dataset_num
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 141                6.7               3.0                5.2               2.3
# 142                6.3               2.5                5.0               1.9
# 143                6.5               3.0                5.2               2.0
# 144                6.2               3.4                5.4               2.3
# 145                5.9               3.0                5.1               1.8
#
# [146 rows x 4 columns]

# %%
# Datos normalizados
print(type(dataset_normal))
print(dataset_normal.shape)
print(dataset_normal.ndim)

dataset_normal
# Out:
# <class 'numpy.ndarray'>
# (146, 4)
# 2
# array([[0.2       , 0.625     , 0.03508772, 0.04166667],
#        [0.14285714, 0.41666667, 0.03508772, 0.04166667],
#        [0.08571429, 0.5       , 0.01754386, 0.04166667],
#        [0.05714286, 0.45833333, 0.05263158, 0.04166667],
#        [0.17142857, 0.66666667, 0.03508772, 0.04166667],
#        [0.28571429, 0.79166667, 0.0877193 , 0.125     ],
#        [0.05714286, 0.58333333, 0.03508772, 0.08333333],
#        [0.17142857, 0.58333333, 0.05263158, 0.04166667],
#        [0.        , 0.375     , 0.03508772, 0.04166667],
#        [0.14285714, 0.45833333, 0.05263158, 0.        ],
#        [0.28571429, 0.70833333, 0.05263158, 0.04166667],
#        [0.11428571, 0.58333333, 0.07017544, 0.04166667],
#        [0.11428571, 0.41666667, 0.03508772, 0.        ],
#        [0.4       , 0.83333333, 0.        , 0.04166667],
#        [0.37142857, 1.        , 0.05263158, 0.125     ],
#        [0.28571429, 0.79166667, 0.01754386, 0.125     ],
# ...

# %%
# Lo convertimos en un DataFrame, añadiendole sus etiquetas
df_normal = pd.DataFrame(dataset_normal, columns=dataset_num.columns)
print(type(df_normal))
df_normal
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0             0.200000          0.625000           0.035088          0.041667
# 1             0.142857          0.416667           0.035088          0.041667
# 2             0.085714          0.500000           0.017544          0.041667
# 3             0.057143          0.458333           0.052632          0.041667
# 4             0.171429          0.666667           0.035088          0.041667
# ..                 ...               ...                ...               ...
# 141           0.657143          0.416667           0.701754          0.916667
# 142           0.542857          0.208333           0.666667          0.750000
# 143           0.600000          0.416667           0.701754          0.791667
# 144           0.514286          0.583333           0.736842          0.916667
# 145           0.428571          0.416667           0.684211          0.708333
# ...

# %%
# Verificar los valores mínimos y los máximos
df_normal.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         146.000000        146.000000         146.000000
# mean            0.421331          0.436073           0.459745
# std             0.233031          0.180872           0.306366
# min             0.000000          0.000000           0.000000
# 25%             0.207143          0.333333           0.070175
# 50%             0.400000          0.416667           0.561404
# 75%             0.571429          0.541667           0.684211
# max             1.000000          1.000000           1.000000
#
#        petal width (cm)
# count        146.000000
# mean           0.469178
# std            0.314521
# min            0.000000
# 25%            0.083333
# 50%            0.500000
# 75%            0.708333
# max            1.000000

# %%
# Visualizar la normalización para el ancho de pétalo
plt.plot(dataset_num['petal width (cm)'], color = 'green')
plt.plot(df_normal['petal width (cm)'], color = 'red')
plt.title('petal width (cm)')
plt.legend(['Datos originales', 'Datos normalizados (MinMaxScaler)'])
plt.show()

# %%
# Visualizar las medidas de pétalo para los dos dataframes
fig, axes = plt.subplots(1,2, figsize=(16,7))

sns.scatterplot(x=dataset_num['petal width (cm)'], y=dataset_num['petal length (cm)'], hue=dataset['label'], ax=axes[0])
axes[0].set_title("Datos originales")

sns.scatterplot(x=df_normal['petal width (cm)'], y=df_normal['petal length (cm)'], hue=dataset['label'], ax=axes[1])
axes[1].set_title("Datos normalizados (MinMaxScaler)")

plt.show()

# %% [markdown]
# Se puede apreciar que **se mantienen las relaciones y las proporciones entre las variables**, aunque el rango y la escala se haya cambiado al normalizar los datos.

# %% [markdown]
# ### **Planteamiento del problema**: predecir la longitud del sépalo (cm) de las flores iris

# %% [markdown]
# Estableceremos las **longitudes de los pétalos** como la variable ***X*** y el **largo de los sépalos** como la variable ***y*** (variable objetivo).
#
# Recordamos que en el modelo de regresión lineal simple, sólo tenemos dos variables. Por lo tanto el resto de los datos del dataset no nos interesarán para este ejercicio.

# %%
X = dataset_num['petal length (cm)']
y = dataset_num['sepal length (cm)']

print(X)
print(y)
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 141    5.2
# 142    5.0
# 143    5.2
# 144    5.4
# 145    5.1
# Name: petal length (cm), Length: 146, dtype: float64
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 141    6.7
# 142    6.3
# 143    6.5
# 144    6.2
# 145    5.9
# Name: sepal length (cm), Length: 146, dtype: float64

# %% [markdown]
# ### **Paso 1.**  Obtención y preparación de datos

# %% [markdown]
# ### *Estructura de datos (sklearn)*
# Para entrenar los modelos con la librería sklearn, los datos deben de estar como arrays numericos (como **numpy array bidimensional**) con esta etructura:
# **(filas = muestras,    columnas = atributos)**

# %%
# No será suficiente si solo sacamos los valores numericos
print(X.values)
print(X.values.shape)
X.values.ndim
# Out:
# [1.4 1.4 1.3 1.5 1.4 1.7 1.4 1.5 1.4 1.5 1.5 1.6 1.4 1.2 1.5 1.3 1.4 1.7
#  1.5 1.7 1.5 1.7 1.6 1.6 1.5 1.4 1.6 1.6 1.5 1.5 1.4 1.5 1.2 1.3 1.4 1.3
#  1.5 1.3 1.3 1.3 1.6 1.4 1.6 1.4 1.5 1.4 4.7 4.5 4.9 4.  4.6 4.5 4.7 3.3
#  4.6 3.9 3.5 4.2 4.  4.7 3.6 4.4 4.5 4.1 4.5 3.9 4.8 4.  4.9 4.7 4.3 4.4
#  4.8 5.  4.5 3.5 3.8 3.7 3.9 5.1 4.5 4.5 4.7 4.4 4.1 4.  4.4 4.6 4.  3.3
#  4.2 4.2 4.2 4.3 3.  4.1 6.  5.1 5.9 5.6 5.8 6.6 4.5 6.3 5.8 6.1 5.1 5.3
#  5.5 5.  5.1 5.3 5.5 6.7 6.9 5.  5.7 4.9 6.7 4.9 5.7 6.  4.8 4.9 5.6 5.8
#  6.1 6.4 5.6 5.1 5.6 6.1 5.6 5.5 4.8 5.4 5.6 5.1 5.1 5.9 5.7 5.2 5.  5.2
#  5.4 5.1]
# (146,)
# 1

# %% [markdown]
# Tenemos que **restructurar** los datos para que tengan la forma adecuada. Podemos aplicar el ``reshape(-1)`` que es para mantener esa dimensión de tamaño indefinido y hacer que se ajuste al resto de las dimensiones. Es decir por ejemplo ``X.values.reshape(-1,1)`` nos dará un array en que hemos especificado que queremos que tenga 1 columna. Por tanto tendremos que usar las filas necesarias para que "quepan" todos los datos.

# %%
# Convertir los arrays 1D a arrays bidimensionales (2D)
X = X.values.reshape(-1,1)
y = y.values.reshape(-1,1)

# %%
print(X)
print(X.shape)
X.ndim
# Out:
# [[1.4]
#  [1.4]
#  [1.3]
#  [1.5]
#  [1.4]
#  [1.7]
#  [1.4]
#  [1.5]
#  [1.4]
#  [1.5]
#  [1.5]
#  [1.6]
#  [1.4]
#  [1.2]
#  [1.5]
#  [1.3]
#  [1.4]
#  [1.7]
#  [1.5]
#  [1.7]
#  [1.5]
#  [1.7]
#  [1.6]
#  [1.6]
#  [1.5]
#  [1.4]
#  [1.6]
#  [1.6]
#  [1.5]
#  [1.5]
#  [1.4]
#  [1.5]
#  [1.2]
#  [1.3]
#  [1.4]
#  [1.3]
#  [1.5]
#  [1.3]
#  [1.3]
#  [1.3]
#  [1.6]
#  [1.4]
#  [1.6]
#  [1.4]
#  [1.5]
#  [1.4]
#  [4.7]
#  [4.5]
#  [4.9]
#  [4. ]
#  [4.6]
#  [4.5]
#  [4.7]
#  [3.3]
#  [4.6]
#  [3.9]
#  [3.5]
#  [4.2]
#  [4. ]
#  [4.7]
#  [3.6]
#  [4.4]
#  [4.5]
#  [4.1]
#  [4.5]
#  [3.9]
#  [4.8]
#  [4. ]
#  [4.9]
#  [4.7]
#  [4.3]
#  [4.4]
#  [4.8]
#  [5. ]
#  [4.5]
#  [3.5]
#  [3.8]
#  [3.7]
#  [3.9]
#  [5.1]
#  [4.5]
#  [4.5]
#  [4.7]
#  [4.4]
#  [4.1]
#  [4. ]
#  [4.4]
#  [4.6]
#  [4. ]
#  [3.3]
#  [4.2]
#  [4.2]
#  [4.2]
#  [4.3]
#  [3. ]
#  [4.1]
#  [6. ]
#  [5.1]
#  [5.9]
#  [5.6]
#  [5.8]
#  [6.6]
#  [4.5]
#  [6.3]
#  [5.8]
#  [6.1]
#  [5.1]
#  [5.3]
#  [5.5]
#  [5. ]
#  [5.1]
# ...

# %%
print(y)
print(y.shape)
y.ndim
# Out:
# [[5.1]
#  [4.9]
#  [4.7]
#  [4.6]
#  [5. ]
#  [5.4]
#  [4.6]
#  [5. ]
#  [4.4]
#  [4.9]
#  [5.4]
#  [4.8]
#  [4.8]
#  [5.8]
#  [5.7]
#  [5.4]
#  [5.1]
#  [5.7]
#  [5.1]
#  [5.4]
#  [5.1]
#  [5.1]
#  [5. ]
#  [5. ]
#  [5.2]
#  [5.2]
#  [4.7]
#  [4.8]
#  [5.4]
#  [5.2]
#  [5.5]
#  [4.9]
#  [5. ]
#  [5.5]
#  [4.9]
#  [4.4]
#  [5.1]
#  [5. ]
#  [4.5]
#  [4.4]
#  [5. ]
#  [4.8]
#  [5.1]
#  [4.6]
#  [5.3]
#  [5. ]
#  [7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]
#  [5.7]
#  [6.3]
#  [4.9]
#  [6.6]
#  [5.2]
#  [5. ]
#  [5.9]
#  [6. ]
#  [6.1]
#  [5.6]
#  [6.7]
#  [5.6]
#  [5.8]
#  [6.2]
#  [5.6]
#  [5.9]
#  [6.1]
#  [6.3]
#  [6.1]
#  [6.4]
#  [6.6]
#  [6.8]
#  [6.7]
#  [6. ]
#  [5.7]
#  [5.5]
#  [5.5]
#  [5.8]
#  [6. ]
#  [5.4]
#  [6. ]
#  [6.7]
#  [6.3]
#  [5.6]
#  [5.5]
#  [5.5]
#  [6.1]
#  [5.8]
#  [5. ]
#  [5.6]
#  [5.7]
#  [5.7]
#  [6.2]
#  [5.1]
#  [5.7]
#  [6.3]
#  [5.8]
#  [7.1]
#  [6.3]
#  [6.5]
#  [7.6]
#  [4.9]
#  [7.3]
#  [6.7]
#  [7.2]
#  [6.5]
#  [6.4]
#  [6.8]
#  [5.7]
#  [5.8]
# ...

# %%
# Normalizar los datos a escala [0,1]
escalado_x = MinMaxScaler().fit(X)
X_norm = escalado_x.transform(X)

escalado_y = MinMaxScaler().fit(y)
y_norm = escalado_y.transform(y)

print(X_norm)
# Out:
# [[0.03508772]
#  [0.03508772]
#  [0.01754386]
#  [0.05263158]
#  [0.03508772]
#  [0.0877193 ]
#  [0.03508772]
#  [0.05263158]
#  [0.03508772]
#  [0.05263158]
#  [0.05263158]
#  [0.07017544]
#  [0.03508772]
#  [0.        ]
#  [0.05263158]
#  [0.01754386]
#  [0.03508772]
#  [0.0877193 ]
#  [0.05263158]
#  [0.0877193 ]
#  [0.05263158]
#  [0.0877193 ]
#  [0.07017544]
#  [0.07017544]
#  [0.05263158]
#  [0.03508772]
#  [0.07017544]
#  [0.07017544]
#  [0.05263158]
#  [0.05263158]
#  [0.03508772]
#  [0.05263158]
#  [0.        ]
#  [0.01754386]
#  [0.03508772]
#  [0.01754386]
#  [0.05263158]
#  [0.01754386]
#  [0.01754386]
#  [0.01754386]
#  [0.07017544]
#  [0.03508772]
#  [0.07017544]
#  [0.03508772]
#  [0.05263158]
#  [0.03508772]
#  [0.61403509]
#  [0.57894737]
#  [0.64912281]
#  [0.49122807]
#  [0.59649123]
#  [0.57894737]
#  [0.61403509]
#  [0.36842105]
#  [0.59649123]
#  [0.47368421]
#  [0.40350877]
#  [0.52631579]
#  [0.49122807]
#  [0.61403509]
#  [0.42105263]
#  [0.56140351]
# ...

# %% [markdown]
# ### **Paso 2.**  Dividir el dataset en Training y Test set

# %%
# Separar los conjuntos de datos de entrenamiento (Training) y de prueba (Test) para las variables de entrada y salida
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_norm, y_norm, test_size= 0.3, random_state= 101)

# %%
# "test_size" representa la proporción del conjunto de datos a incluir en la división de Test
print(X_train1.size)
print(X_test1.size)
X_train1.size + X_test1.size
# Out:
# 102
# 44
# 146

# %% [markdown]
# ### **Paso 3.** Aplicar el modelo de regresión lineal simple

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %% [markdown]
# ### **Paso 4.** Entrenar el modelo de regresión lineal simple con los datos de entrenamiento

# %%
# Training/Fitting para entrenar el modelo
lr.fit(X_train1, y_train1)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Paso 4.** Obtener las predicciones

# %%
# Lanzar una predicción (siempre indicando un objeto de 2D)
lr.predict([[0.8]])
# Out:
# array([[0.63723583]])

# %%
# Calcular las estimaciones ajustadas por el modelo (predicciones del conjunto de entrenamiento)
pred_train1 = lr.predict(X_train1)
pred_train1
# Out:
# array([[0.47202638],
#        [0.49465781],
#        [0.16650205],
#        [0.14387062],
#        [0.42676352],
#        [0.49465781],
#        [0.49465781],
#        [0.13255491],
#        [0.13255491],
#        [0.4833421 ],
#        [0.14387062],
#        [0.49465781],
#        [0.46071066],
#        [0.61913068],
#        [0.15518634],
#        [0.56255211],
#        [0.42676352],
#        [0.56255211],
#        [0.15518634],
#        [0.64176212],
#        [0.51728924],
#        [0.49465781],
#        [0.59649925],
#        [0.43807923],
#        [0.53992067],
#        [0.13255491],
#        [0.14387062],
#        [0.15518634],
#        [0.50597353],
#        [0.49465781],
#        [0.51728924],
#        [0.16650205],
#        [0.55123639],
#        [0.16650205],
#        [0.15518634],
#        [0.52860496],
#        [0.73228784],
#        [0.14387062],
#        [0.13255491],
#        [0.74360356],
#        [0.6983407 ],
#        [0.76623499],
#        [0.15518634],
# ...

# %%
# Calcular las predicciones de pruebas a ciegas (conjunto de test)
pred_test1 = lr.predict(X_test1)
pred_test1
# Out:
# array([[0.42676352],
#        [0.32492208],
#        [0.14387062],
#        [0.40413209],
#        [0.12123919],
#        [0.44939495],
#        [0.43807923],
#        [0.4833421 ],
#        [0.14387062],
#        [0.51728924],
#        [0.46071066],
#        [0.46071066],
#        [0.65307783],
#        [0.6304464 ],
#        [0.14387062],
#        [0.46071066],
#        [0.14387062],
#        [0.35886922],
#        [0.43807923],
#        [0.66439355],
#        [0.53992067],
#        [0.67570926],
#        [0.14387062],
#        [0.43807923],
#        [0.13255491],
#        [0.61913068],
#        [0.15518634],
#        [0.74360356],
#        [0.61913068],
#        [0.70965641],
#        [0.57386782],
#        [0.52860496],
#        [0.50597353],
#        [0.35886922],
#        [0.55123639],
#        [0.17781777],
#        [0.16650205],
#        [0.61913068],
#        [0.53992067],
#        [0.16650205],
#        [0.12123919],
#        [0.53992067],
#        [0.60781497],
# ...

# %%
# Desnormalizamos las variables para volver a la escala original
X_train1_des = escalado_x.inverse_transform(X_train1)
X_test1_des = escalado_x.inverse_transform(X_test1)


y_test1_des = escalado_y.inverse_transform(y_test1)
pred_test1_des = escalado_y.inverse_transform(pred_test1)
pred_train1_des = escalado_y.inverse_transform(pred_train1)

# %%
pred_test1_des
# Out:
# array([[5.89367231],
#        [5.53722726],
#        [4.90354718],
#        [5.8144623 ],
#        [4.82433717],
#        [5.97288232],
#        [5.93327731],
#        [6.09169734],
#        [4.90354718],
#        [6.21051235],
#        [6.01248733],
#        [6.01248733],
#        [6.68577241],
#        [6.6065624 ],
#        [4.90354718],
#        [6.01248733],
#        [4.90354718],
#        [5.65604228],
#        [5.93327731],
#        [6.72537742],
#        [6.28972236],
#        [6.76498242],
#        [4.90354718],
#        [5.93327731],
#        [4.86394218],
#        [6.5669574 ],
#        [4.94315219],
#        [7.00261245],
#        [6.5669574 ],
#        [6.88379744],
#        [6.40853738],
#        [6.25011736],
#        [6.17090735],
#        [5.65604228],
#        [6.32932737],
#        [5.0223622 ],
#        [4.98275719],
#        [6.5669574 ],
#        [6.28972236],
#        [4.98275719],
#        [4.82433717],
#        [6.28972236],
#        [6.52735239],
# ...

# %%
# Visualizar la normalización para el ancho de pétalo
plt.plot(pred_test1_des, color = 'green')
plt.plot(pred_test1, color = 'red')
plt.title('sepal length (cm)')
plt.legend(['Predicción en escala original', 'Predicciones normalizadas'])
plt.show()

# %% [markdown]
# ### **Paso 5.** Visualizamos los resultados

# %% [markdown]
# Los **puntos verdes** representan los datos que teníamos guardados en el *y_test* y la línea azul se trata de la **recta de regresión** que hemos generado con el modelo de regresión lineal simple, ajustando el algoritmo a los datos de entrenamiento (los puntos negros). Aquí los **puntos rojos** muestran la salida de nuestro modelo para el conjunto de test.

# %%
# Dibujar la recta de regresión 
plt.plot(X_train1_des, pred_train1_des, color = 'blue')

# Dibujar los puntos ajustados al modelo para el conjunto de entrenamiento (Training)
plt.scatter(X_train1_des, pred_train1_des, color = 'black')

# Dibujar los puntos obtenidos del modelo para el conjunto de prueba (Test)
plt.scatter(X_test1_des, pred_test1_des, color = 'red')

# Dibujar las medidas reales para el conjunto de prueba (Test)
plt.scatter(X_test1_des, y_test1_des, color = 'green')

plt.title('petal length (cm) vs sepal length (cm)')
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.show()

# %% [markdown]
# Vamos ahora a comparar nuestra predicción con los datos reales que tenemos en otra gráfica.
#
# La línea **diagonal** representa el **modelo ideal**, en el cual, cada predicción coincide con el valor real. Cuanto más alejados estén los punto de esta diagonal peor serán nuestras predicciones.

# %%
# Comparación de valores reales vs. predichos
plt.scatter(y_test1_des, pred_test1_des, color = 'red')
plt.plot(y_test1_des, y_test1_des, color = 'blue')
plt.title('valores_reales vs. predicción')
plt.xlabel('y_test1_des')
plt.ylabel('pred_test1_des')
plt.show()

# %% [markdown]
# ### **Paso 5.**  Evaluación del modelo a través de sus métricas

# %% [markdown]
# Hay diferentes métricas de la evaluación del modelo de regresión, pero la mayoría de ellos se basan en la similitud de los valores pronosticados con reales.
#
# Para entender estas métricas primero vamos a definir qué es el error de un modelo de regresión.
#
# **El error de un modelo de regresión** es la diferencia entre los datos puntuales y la línea de tendencia (recta regresión lineal en el caso de regresión lineal simple) generada por el algoritmo.
#
# El error puede ser determinado de multiples maneras:
# * Error medio absoluto (**MAE**) es la media del valor absoluto de los errores. Es la medida más fácil de entender, ya que es sólo el error promedio.
# * Error cuadrático medio (**MSE**) es la media de los errores al cuadrado. Es más popular que el error medio absoluto porque el enfoque se orienta más hacia grandes errores. Esto se debe a que el término al cuadrado aumenta exponencialmente los errores más grandes en comparación con los más pequeños.
# * Raiz cuadrada del error cuadrático medio (**RMSE**) es la raíz cuadrada de la anterior medida.
#
# ![image.png](attachment:image.png)
#
# **R-cuadrado** (también se conoce como **coeficiente de determinación**) no es un error, si no, una métrica popular para la precisión del modelo. Determina la capacidad de un modelo para predecir futuros resultados, es decir, representa como de cerca a realidad están los valores de los datos de la línea de regresión ajustada.
#
# El mejor resultado posible es 1.0, y ocurre cuando la predicción coincide con los valores de la variable objetivo. $R^{2}$ puede tomar valores negativos pues la predicción puede ser arbitrariamente mala. Cuanto **más alto sea el $R^{2}$, mejor** encaja el modelo a los datos.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Métricas de evaluación del modelo
print('Mean Absolute Error (MAE):', mean_absolute_error(y_test1_des, pred_test1_des)) #Hemos equivocado en un promedio
print('Mean Squared Error (MSE):', mean_squared_error(y_test1_des, pred_test1_des))
print('Root Mean Squared Error (RMSE):', np.sqrt(mean_squared_error(y_test1_des, pred_test1_des)))
print('R^2 coefficient of determination:', r2_score(y_test1_des, pred_test1_des))
# Out:
# Mean Absolute Error (MAE): 0.3415162480180699
# Mean Squared Error (MSE): 0.18534114649475547
# Root Mean Squared Error (RMSE): 0.43051265544087725
# R^2 coefficient of determination: 0.7387793950235169

# %% [markdown]
# ### **`Ejercicio 6.1`**
#
# Vamos a realizar un planteamiento distinto del problema: **predecir el ancho del pétalo (cm) de las flores de iris**. Tomaremos como ***X*** el largo del pétalo (cm)(lo que sé), y como ***y*** el ancho del pétalo (cm)(lo que quiero adivinar con el input anterior).
#
# **`6.1.1`** Realiza los mismos pasos que el ejemplo anterior, construyendo un modelo de *Regresión lineal* para este nuevo planteamiento, partiendo del dataset filtrado (`dataset_num`) y considerando:
#
#  - para _train_test_split_: `test_size=0.3`
#  - para _train_test_split_: `random_state=101`
#
# **`6.1.2`** Visualiza los resultados de tu modelo creando las dos gráficas del ejemplo anterior (*"Recta de regresión"* y *"Valores reales vs. predichos"*)
#
# **`6.1.3`** Calcula diferentes métricas para evaluar tu modelo y explica si este nuevo modelo tiene un rendimiendo superior o inferior que el modelo entrenado en el ejemplo anterior en la sesión (_predecir la longitud del sépalo_):
# - MAE
# - MSE
# - RMSE
# - $R^2$

# %%
## Solución
# Ejercicio 6.1.1
X = dataset_num['petal length (cm)']
y = dataset_num['petal width (cm)']
dataset_num
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 141                6.7               3.0                5.2               2.3
# 142                6.3               2.5                5.0               1.9
# 143                6.5               3.0                5.2               2.0
# 144                6.2               3.4                5.4               2.3
# 145                5.9               3.0                5.1               1.8
#
# [146 rows x 4 columns]

# %%
#PASO 1 OBTENCIÓN Y PREPARACIÓN DE DATOS.

#Comprobamos las dimensiones de nuestros datos, ya que para sklearn necesitamos una numpy array bidimensional.

print(X.values.ndim)
print(y.values.ndim)

#Convertimos los arrays a 2D

X = X.values.reshape(-1,1)
y = y.values.reshape(-1,1)

#Normalizamos los datos a escala [0,1]
escalado_x = MinMaxScaler().fit(X)
X_norm = escalado_x.transform(X)

escalado_y = MinMaxScaler().fit(y)
y_norm = escalado_y.transform(y)
# Out:
# 1
# 1

# %%
#PASO 2 DIVIDIR EL DATASET EN TRAINING Y TEST SET

#Separar en training y test.
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_norm, y_norm, test_size = 0.3, random_state= 101)

# %%
#PASO 3 APLICAR MODELO DE REGRESION LINEAL SIMPLE
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
#PASO 4 ENTRENAR EL MODELO DE REGRESIÓN LINEAL SIMPLE CON LOS DATOS DE ENTRENAMIENTO.
lr.fit(X_train1, y_train1)
# Out:
# LinearRegression()

# %%
#PASO 5 OBTENEMOS LAS PREDICCIONES

#Lanzar prediccion.

lr.predict([[0.8]])

#Calcular las predicciones dle conjunto de entrenamiento.
pred_train1 = lr.predict(X_train1)
#Calcular las predicciones de pruebas a ciegas (test)
pred_test1 = lr.predict(X_test1)
#Desnormalizamos los datos.
X_train1_des = escalado_x.inverse_transform(X_train1)
X_test1_des = escalado_x.inverse_transform(X_test1)

y_test1_des = escalado_y.inverse_transform(y_test1)
pred_test1_des = escalado_y.inverse_transform(pred_test1)
pred_train1_des = escalado_y.inverse_transform(pred_train1)
#Visualizar normalización
plt.plot(pred_test1_des, color = "blue")
plt.plot(pred_test1, color = "red")
plt.show()

# %%
## Solución
# Ejercicio 6.1.2
'''Visualiza los resultados de tu modelo creando las dos gráficas del ejemplo anterior (*"Recta de regresión"* y *"Valores reales vs. predichos"*)''' 
#RECTA DE REGRESIÓN
#Dibujar recta
plt.plot(X_train1_des, pred_train1_des, color = 'green')
#Dibujar puntos ajustados al training
plt.scatter(X_train1_des, pred_train1_des, color = 'yellow')
#Dibujar puntos obtenidos por test
plt.scatter(X_test1_des, pred_test1_des, color = 'red')
#Dibujar las medidas para el test
plt.scatter(X_test1_des, y_test1_des, color = 'blue')

plt.title('petal length (cm) vs petal width (cm)')
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()

# %%
#Valores reales vs predichos.
plt.scatter(y_test1_des, pred_test1_des, color = 'red')
plt.plot(y_test1_des, y_test1_des, color = 'blue')
plt.title('Valores reales vs prediccion')
plt.xlabel('y_test1_des')
plt.ylabel('pred_test1_des')
plt.show()

# %%
## Solución
# Ejercicio 6.1.3
'''Calcula diferentes métricas para evaluar tu modelo y explica si este nuevo modelo tiene un rendimiendo superior o inferior que el modelo entrenado en el ejemplo anterior en la sesión (_predecir la longitud del sépalo_):  
- MAE
- MSE
- RMSE
- $R^2$'''
#importo librerias de MAE,MSE,R^^2
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#Métricas de evaluación del modelo
print('Mean Absolute Error (MAE):', mean_absolute_error(y_test1_des, pred_test1_des))
print('Mean Squared Error (MSE):', mean_squared_error(y_test1_des, pred_test1_des))
print('Root Mean Squared Error (RMSE):', np.sqrt(mean_squared_error(y_test1_des, pred_test1_des)))
print('R^^2 coefficient of determination:', r2_score(y_test1_des, pred_test1_des))
# Out:
# Mean Absolute Error (MAE): 0.14124149464690572
# Mean Squared Error (MSE): 0.03428561238028691
# Root Mean Squared Error (RMSE): 0.1851637447782014
# R^^2 coefficient of determination: 0.9343140704110404

# %% [markdown]
# #### Conclusión
# Este nuevo modelo tiene un rendimiento superior ya que su **coeficiente de determinacion** (0.9343140704110404) es mas elevado que en el modelo anterior (0.7387793950235169), ya que este determina la capacidad de un modelo para predecir futuros resultados, siendo 1.0 el mejor resultado posible

# %% [markdown]
# ---

# %% [markdown]
# ## 2.2 Regresión lineal múltiple

# %% [markdown]
# Recordemos que cuando sólamente teníamos una variable (regresión lineal simple) la **ecuación para la regresión lineal** está representada por una ecuación:  $Y = a X + b$.
#
# Donde:
# * Y - Variable dependiente
# * a - Pendiente
# * X - Variable independiente
# * b - Intercept ( sería el corte con el origen en la recta de regresión lineal simple)
#
# Nuestro **objetivo** era determinar el valor de los coeficientes ***a*** y ***b*** que proporcionan el error mínimo cuadrado para el conjunto de datos dado.
#
# En este caso tendremos un dato con **N variables**, llamaremos al dato ***X***. Es decir $X = [x_{0}, x_{1}, x_{2}, ..., x_{N}]$
#
# También tenemos que expandir los parámetros ***a*** para que cada parámetro vaya con una variable. Es decir $A = [a_{0}, a_{1}, a_{2}, ..., a_{N}]$
#
# Cuando tenemos solamente una variable y con $a_{0} = a, a_{1} = b$ nos quedará una expresión equivalente a la original.
#
# En general, denotaremos $y=AX$ (usando el producto matricial) a la **ecuación lineal que describe la regresión lineal múltiple**.
#
# Desarrollando esto nos quedaría: $y=a_{0}x_{0}+ a_{1}x_{1}+ a_{2}x_{2}+ ...+ a_{N}x_{N}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ejemplo Regresión lineal múltiple - Boston housing dataset

# %% [markdown]
# Como ejemplo, desarrollaremos un modelo para **predecir el precio de las casas en Boston** de acuerdo con varias características como el número de habitaciones que cuenta la vivienda, el tiempo que ha estado ocupada y la distancia que se encuentra la misma de los centros de trabajo de Boston.
#
# De esta forma tenemos diferentes variables que se tomarán en cuenta para diseñar nuestro modelo. Para este análisis vamos a utilizar el dataset disponible en la librería scikit-learn correspondiente al *Boston Housing*.

# %% [markdown]
# Características del conjunto de datos:
#
#     -Número de muestras: 506
#
#     -Número de atributos: 13 predictivo numérico / categórico
#
#     -Median value (atributo 14) suele ser el objetivo.
#
# Información de atributos (en orden):
#
#         - CRIM tasa de delincuencia per cápita por ciudad
#         - Proporción ZN de terreno residencial dividido en zonas para lotes de más de 25,000 pies cuadrados.
#         - Proporción INDUS de acres comerciales no minoristas por ciudad
#         - Variable ficticia CHAS Charles River (= 1 si el tramo limita con el río; 0 en caso contrario)
#         - Concentración de óxidos nítricos NOX (partes por 10 millones)
#         - RM número medio de habitaciones por vivienda
#         - Proporción de EDAD de las unidades ocupadas por el propietario construidas antes de 1940
#         - Distancias ponderadas DIS a cinco centros de empleo de Boston
#         - Índice RAD de accesibilidad a carreteras radiales
#         - IMPUESTO Tasa de impuesto a la propiedad de valor total por \$ 10,000\
#         - PTRATIO Ratio maestro-alumno por municipio
#         - B 1000 (Bk - 0.63) ^ 2 donde Bk es la proporción de negros por ciudad
#         - LSTAT % menor estatus de la población
#         - MEDV Valor medio de las viviendas ocupadas por el propietario en \$ 1000\

# %% [markdown]
# > #### **¡Nota importante!**
# > El conjunto de datos de precios de la vivienda de _Boston_ tiene un **`problema ético`**:
#   como se investigó en [este artículo](https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8), los autores de este conjunto de datos diseñaron una variable no invertible **"B" asumiendo que la autosegregación racial tuvo un impacto positivo en los precios de la vivienda**.
# >
# >  Además, el objetivo de la investigación que condujo a la creación de este conjunto de datos fue estudiar el impacto de la calidad del aire, pero **no proporcionó una demostración adecuada de la validez de dicha suposición**.
#  Por lo tanto, los mantenedores de _scikit-learn_ **desaconsejan fuertemente** el uso de este conjunto de datos a menos que el propósito del  código sea **estudiar y educar sobre cuestiones éticas** en la ciencia de datos y el aprendizaje automático.
# >

# %% [markdown]
# ### **Paso 1.** Importar datos para el modelo

# %%
# Importamos los datos de la misma librería de scikit-learn
#from sklearn.datasets import load_boston
#boston = load_boston()
boston = pd.read_csv("dataset_boston.csv", index_col=0)

# %%
# Veamos los nombres de las columnas
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %% [markdown]
# Para poder analizar los datos, convertiremos todos estos datos en un dataframe:

# %%
# Convertir los datos en pandas dataframe
dataframe_x = pd.DataFrame(boston.data, columns = boston.feature_names)

# La variable dependiente es el target y la llamammos dataframe_y
dataframe_y = pd.DataFrame(boston.target, columns = ['target'])

# Combinamos ambos para obtener un dataframe con todas las variables explicativas y la variable objetivo
df_boston = dataframe_x.join(dataframe_y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j3/km7zm3k92gb35xzx0v7c_5pm0000gn/T/ipykernel_6402/3585917858.py in ?()
#       1 # Convertir los datos en pandas dataframe
# ----> 2 dataframe_x = pd.DataFrame(boston.data, columns = boston.feature_names)
#       3
#       4 # La variable dependiente es el target y la llamammos dataframe_y
#       5 dataframe_y = pd.DataFrame(boston.target, columns = ['target'])
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %% [markdown]
# Veamos que forma tiene nuestro dataframe

# %%
df_boston = boston

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 59.3 KB

# %% [markdown]
# ### **Planteamiento del problema:** predecir  el precio de las casas en _Boston_ de acuerdo al número de habitaciones que cuenta la vivienda, el tiempo que ha estado ocupada y la distancia que se encuentra de los centros de trabajo.
#
# Vamos a definir las variables.
#
# Como variables independientes X, nos fijaremos en las tres columnas del dataset:
#  - `RM`:  número medio de habitaciones por vivienda.
#  - `AGE`: Proporción de EDAD de las unidades ocupadas por el propietario construidas antes de 1940.
#  - `DIS`: Distancias ponderadas a cinco centros de empleo de Boston.
#
# Como variable dependiente (target) :
# - `MEDV`: Valor medio de las viviendas ocupadas por el propietario en $ 1000

# %%
# Datos de entrada al modelo
df_boston[['RM', 'AGE', 'DIS']]
# Out:
#         RM   AGE     DIS
# 0    6.575  65.2  4.0900
# 1    6.421  78.9  4.9671
# 2    7.185  61.1  4.9671
# 3    6.998  45.8  6.0622
# 4    7.147  54.2  6.0622
# ..     ...   ...     ...
# 501  6.593  69.1  2.4786
# 502  6.120  76.7  2.2875
# 503  6.976  91.0  2.1675
# 504  6.794  89.3  2.3889
# 505  6.030  80.8  2.5050
#
# [506 rows x 3 columns]

# %%
# La variable objetivo
df_boston['target']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: target, Length: 506, dtype: float64

# %%
# Definimos los datos del modelo con la estructura adecuada para sklearn
X_multiple = df_boston[['RM', 'AGE', 'DIS']].values
y_multiple = df_boston['target'].values.reshape(-1,1)

# %%
X_multiple
# Out:
# array([[ 6.575 , 65.2   ,  4.09  ],
#        [ 6.421 , 78.9   ,  4.9671],
#        [ 7.185 , 61.1   ,  4.9671],
#        ...,
#        [ 6.976 , 91.    ,  2.1675],
#        [ 6.794 , 89.3   ,  2.3889],
#        [ 6.03  , 80.8   ,  2.505 ]])

# %%
y_multiple
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [27.1],
#        [16.5],
#        [18.9],
#        [15. ],
#        [18.9],
#        [21.7],
#        [20.4],
#        [18.2],
#        [19.9],
#        [23.1],
#        [17.5],
#        [20.2],
#        [18.2],
#        [13.6],
#        [19.6],
#        [15.2],
#        [14.5],
#        [15.6],
#        [13.9],
#        [16.6],
#        [14.8],
#        [18.4],
#        [21. ],
#        [12.7],
#        [14.5],
#        [13.2],
#        [13.1],
#        [13.5],
#        [18.9],
#        [20. ],
#        [21. ],
#        [24.7],
#        [30.8],
#        [34.9],
#        [26.6],
#        [25.3],
#        [24.7],
#        [21.2],
#        [19.3],
#        [20. ],
#        [16.6],
#        [14.4],
#        [19.4],
#        [19.7],
#        [20.5],
#        [25. ],
#        [23.4],
#        [18.9],
#        [35.4],
#        [24.7],
#        [31.6],
# ...

# %% [markdown]
# ### **Paso 2.**  Dividir el dataset en Training y Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_multiple, y_multiple, test_size=0.2, random_state=100)

# %% [markdown]
# ### **Paso 3.** Aplicar el modelo de regresión lineal múltiple

# %%
# Defino el algoritmo a utilizar
lr_multiple = LinearRegression()

# %% [markdown]
# Se puede apreciar que usamos el mismo algoritmo que utilizamos en el ejemplo de Regresión Lineal Simple, esto se debe a que todos los algoritmos relacionados a Regresión Lineal utilizan esta misma librería, es decir no tiene que configurarse nada adicional para implementarla.
#
# Definido el algoritmo ahora procedemos a entrenar nuestro modelo con los datos correspondiente, para ello utilizamos la operación ``fit``.

# %% [markdown]
# ### **Paso 4.** Entrenar el modelo de regresión lineal simple con los datos de prueba

# %%
# Entrenamos el modelo
lr_multiple.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Paso 5.** Lanzar las predicciones

# %%
#Realizo una predicción
y_pred_multiple = lr_multiple.predict(X_test)

# %% [markdown]
# Obtenemos los coeficientes del "***hiperplano***" de regresión

# %%
print('DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE')
print('\n', 'Valor de las pendientes o coeficientes "a":')
print(lr_multiple.coef_)
print('\n', 'Valor de la intersección o coeficiente "b":')
print(lr_multiple.intercept_)
# Out:
# DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE
#
#  Valor de las pendientes o coeficientes "a":
# [[ 8.17426638 -0.10345902 -0.56614285]]
#
#  Valor de la intersección o coeficiente "b":
# [-19.46435667]

# %% [markdown]
# ### **Paso 6.**  Evaluación del modelo a través de sus métricas

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Métricas para evaluar la calidad del modelo
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred_multiple))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_test, y_pred_multiple)*100)
print('Mean Squared Error:', mean_squared_error(y_test, y_pred_multiple))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred_multiple)))
print('R^2 coefficient of determination:', r2_score(y_test, y_pred_multiple))
# Out:
# Mean Absolute Error: 4.201576308503821
# Mean Absolute Percentage Error: 25.80253644747504
# Mean Squared Error: 45.403744974033955
# Mean Root Squared Error: 6.738230106937129
# R^2 coefficient of determination: 0.5299543467684696

# %%
# Info sobre los rangos de la variable objetivo
df_boston['target'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: target, dtype: float64

# %% [markdown]
# Un diagrama de dispersión (**scatterplot**) es un tipo de diagrama matemático que utiliza las coordenadas cartesianas para mostrar los valores de dos variables para un conjunto de datos.
#
# En este caso vamos a comparar y_pred_multiple con y_test
#
# La línea diagonal representa el modelo ideal, en el cual, cada predicción coincide con el valor real.

# %%
# visualizamos resultados
plt.scatter(y_test, y_pred_multiple, color = 'red')
plt.plot(y_test, y_test, color = 'blue')
plt.title('y_test vs y_pred_multiple')
plt.xlabel('y_test')
plt.ylabel('y_pred_multiple')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### **`Ejercicio 6.2`**
#
# Vamos a realizar un planteamiento diferente del problema: **predecir el precio de las viviendas en Boston** considerando el conjunto de las siguienetes variables:
#
#  - **LSTAT** % menor estatus de la población
#  - **RM** número medio de habitaciones por vivienda
#  - **PTRATIO** Ratio maestro-alumno por municipio
#
#
# **`6.2.1`** Realiza los mimso pasos que el ejemplo anterior, construyendo un modelo de *Regresión lineal múltiple* para este nuevo conjunto de variables de entrada al modelo considerando:
#
#  - para _train_test_split_: `test_size=0.2`
#  - para _train_test_split_: `random_state=100`
#
# **`6.2.2`** Visualiza los resultados de tu modelo comparando los valores reales y los predichos para el periodo de prueba (*"Valores reales vs. predichos"*)
#
# **`6.2.3`** Calcula diferentes métricas para evaluar tu modelo y explica si este nuevo modelo tiene un rendimiendo superior o inferior que el modelo entrenado en el ejemplo anterior:
# - MAE
# - MAPE
# - MSE
# - RMSE
# - $R^2$

# %%
## Solución
# Ejercicio 6.2.1
'''**`6.2.1`** Realiza los mimso pasos que el ejemplo anterior, construyendo un modelo de *Regresión lineal múltiple* para este nuevo conjunto de variables de entrada al modelo considerando:  

 - para _train_test_split_: `test_size=0.2`
 - para _train_test_split_: `random_state=100`'''
boston = pd.read_csv('dataset_boston.csv', index_col=0)
#definimos las variables y los datos del modelo, haciendo reshape para tener 2D
x_multiple = boston[['LSTAT','RM','PTRATIO']].values
y_multiple = boston['target'].values.reshape(-1,1)

# %%
#Dividir dataset en training y test//Aplicar modelo de regresion lineal multiple y entenar
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_multiple, y_multiple, test_size=0.2, random_state=100)

#definir algoritmo
lr_multiple = LinearRegression()
#entrenar modelo
lr_multiple.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#lanzar predicciones 
y_pred_multiple = lr_multiple.predict(x_test)
print('Datos del modelo regresion lineal multiple\nValor de las pendientes o coeficientes "a":', lr_multiple.coef_,'\nValor de la interseccion o coeficiente "b":',lr_multiple.intercept_)
# Out:
# Datos del modelo regresion lineal multiple
# Valor de las pendientes o coeficientes "a": [[-0.55011883  4.33059077 -0.94825859]]
# Valor de la interseccion o coeficiente "b": [19.90112017]

# %%
## Solución
# Ejercicio 6.2.2
'''**`6.2.2`** Visualiza los resultados de tu modelo comparando los valores reales y los predichos para el periodo de prueba (*"Valores reales vs. predichos"*)'''
plt.scatter(y_test, y_pred_multiple, color = 'blue')
plt.plot(y_test, y_test, color = 'red')
plt.title('valores reales vs. predichos')
plt.xlabel('y_test')
plt.ylabel('y_pred_multiple')
plt.show()

# %%
## Solución
# Ejercicio 6.2.3
'''**`6.2.3`** Calcula diferentes métricas para evaluar tu modelo y explica si este nuevo modelo tiene un rendimiendo superior o inferior que el modelo entrenado en el ejemplo anterior:  
- MAE
- MAPE
- MSE
- RMSE
- $R^2$'''
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred_multiple))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_test, y_pred_multiple)*100)
print('Mean Squared Error:', mean_squared_error(y_test, y_pred_multiple))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred_multiple)))
print('R^2 coefficient of determination:', r2_score(y_test, y_pred_multiple))
# Out:
# Mean Absolute Error: 3.8418946022575584
# Mean Absolute Percentage Error: 20.78198247622258
# Mean Squared Error: 29.063582545308233
# Mean Root Squared Error: 5.391065065950163
# R^2 coefficient of determination: 0.6991170959450448

# %% [markdown]
# #### Conclusión
# Este nuevo modelo tiene un rendimiento superior que el modelo anterior ya que su **coeficiente de determinación** (0.6991170959450448) es mayor que el anterior (0.5299543467684696)
